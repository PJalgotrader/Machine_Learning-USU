# %% [markdown]
# # Prof. Pedram Jahangiry
#
# You need to make a copy to your own Google drive if you want to edit the original notebook! Start by opening this notebook on Colab 👇
#
# <a href="https://colab.research.google.com/github/PJalgotrader/Machine_Learning-USU/blob/main/Lectures%20and%20codes/ML%20spring%202023/Module%206-%20Penalized%20Regressions/regularization_synthetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# ![logo](https://upload.wikimedia.org/wikipedia/commons/4/44/Huntsman-Wordmark-with-USU-Blue.gif#center)
#
#
# ## 🔗 Links
#
# [![linkedin](https://img.shields.io/badge/LinkedIn-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pedram-jahangiry-cfa-5778015a)
#
# [![Youtube](https://img.shields.io/badge/youtube_channel-1DA1F2?style=for-the-badge&logo=youtube&logoColor=white&color=FF0000)](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ)
#
# [![Twitter URL](https://img.shields.io/twitter/url/https/twitter.com/PedramJahangiry.svg?style=social&label=Follow%20%40PedramJahangiry)](https://twitter.com/PedramJahangiry)
#
#
# ---

# %% [markdown]
# # Regularization: Penalized regression
#
# Regularization force the learning algorithm to build a less complex model . In practice, that often leads to slightly higher bias but significantly reduces the variance. The most common penalized regression models are:
#
# 1. Ridge regression
# 2. Lasso regression
# 3. Elastic Net regression
#
# In this notebook we will explore the three methods and compare their results with a multiple liear regression model applied to our synthetic data generated from the following  true model f(x)
#
# $$y =f(x)= x + 2x^2- 3 x^3 + \epsilon$$
#
# The target variable is **y** and the features are 5 polynomial features of **X**. Namely, $X_1= X$, $X_2= X^2$, $X_3= X^3$ and etc.

# %% [markdown]
# First we need to import the libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  #if you want to use seaborn themes with matplotlib functions
import warnings
warnings.filterwarnings('ignore')

# %%
rand_state= 1000

# %%
df=pd.read_csv('https://raw.githubusercontent.com/PJalgotrader/Machine_Learning-USU/main/data/Regularization_synthetic.csv')

# %%
df.head()
# Out:
#          X1        X2        X3        X4         X5          y
# 0  1.668068  2.782452  4.641320  7.742038  12.914249  -3.901562
# 1  0.925862  0.857220  0.793667  0.734826   0.680348  -0.384578
# 2  1.057997  1.119357  1.184276  1.252960   1.325628  12.493677
# 3 -0.920339  0.847024 -0.779549  0.717449  -0.660297  12.237389
# 4  1.299748  1.689346  2.195725  2.853890   3.709339  -3.772851

# %%
sns.scatterplot(x='X1', y='y', data=df)
plt.show()

# %% [markdown]
# **important**: we need to normalize the features before training the models. Why?

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
df_sc= scaler.fit_transform(df)

# %%
df_sc.shape
# Out:
# (100, 6)

# %%
df_sc[:2]
# Out:
# array([[ 1.68559489,  1.10379599,  0.93969261,  0.28529469,  0.20893775,
#         -0.41160092],
#        [ 0.95551657, -0.1126954 ,  0.15582326, -0.19468946, -0.0400858 ,
#         -0.20670883]])

# %%
df_sc = pd.DataFrame(df_sc, columns=df.columns)
df_sc.head()
# Out:
#          X1        X2        X3        X4        X5         y
# 0  1.685595  1.103796  0.939693  0.285295  0.208938 -0.411601
# 1  0.955517 -0.112695  0.155823 -0.194689 -0.040086 -0.206709
# 2  1.085492  0.052941  0.235401 -0.159198 -0.026951  0.543551
# 3 -0.860516 -0.119138 -0.164683 -0.195880 -0.067375  0.528621
# 4  1.323294  0.413098  0.441460 -0.049537  0.021570 -0.404102

# %%
sns.scatterplot(x='X1', y='y', data=df_sc)
plt.show()

# %% [markdown]
# ## Splitting the data

# %%
y = df_sc['y']
X = df_sc.drop('y', axis=1) # be careful, inplace= False

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=rand_state)
X_train.head()
# Out:
#           X1        X2        X3        X4        X5
# 37  1.464631  0.662152  0.606819  0.052327  0.073610
# 44  1.572794  0.870372  0.757779  0.153824  0.130178
# 55  0.275319 -0.619639 -0.003245 -0.244817 -0.053920
# 66 -0.493702 -0.464986 -0.039290 -0.238872 -0.054935
# 82  0.272588 -0.620456 -0.003337 -0.244827 -0.053921

# %% [markdown]
# Let's first run a linear regression (using statsmodels.api)  and see the results as a benchmark.

# %%
import statsmodels.api as sm

# %%
X_test_wc = sm.add_constant(X_test)
X_train_wc = sm.add_constant(X_train)

# %%
model = sm.OLS(y_train, X_train_wc).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.451
# Model:                            OLS   Adj. R-squared:                  0.414
# Method:                 Least Squares   F-statistic:                     12.17
# Date:                Wed, 01 Mar 2023   Prob (F-statistic):           1.28e-08
# Time:                        10:37:02   Log-Likelihood:                -65.981
# No. Observations:                  80   AIC:                             144.0
# Df Residuals:                      74   BIC:                             158.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0870      0.173      0.504      0.616      -0.257       0.431
# X1             0.5370      0.199      2.705      0.008       0.141       0.933
# X2             0.1037      0.302      0.343      0.732      -0.498       0.705
# X3            -2.1339      0.839     -2.543      0.013      -3.806      -0.462
# X4             0.2535      0.861      0.294      0.769      -1.463       1.970
# X5             1.5933      1.669      0.954      0.343      -1.733       4.920
# ==============================================================================
# Omnibus:                       11.757   Durbin-Watson:                   2.213
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               14.171
# Skew:                          -0.701   Prob(JB):                     0.000837
# Kurtosis:                       4.512   Cond. No.                         33.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ----

# %% [markdown]
# # A) Training the models
#
# In this section we will train 4 different models:
# 1. Linear regression (model_linear)
# 2. Ridge regression (model_ridge)
# 3. Lasso regression (model_lasso)
# 4. Elastic Net regression (model_net)

# %%
from sklearn.linear_model import LinearRegression, Ridge,RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV

# %%
model_linear = LinearRegression()
model_ridge = Ridge(alpha=0)
model_lasso = Lasso(alpha=0)
model_net = ElasticNet(alpha=0)

# %%
y_hat_linear= model_linear.fit(X_train, y_train).predict(X_test)
y_hat_ridge = model_ridge.fit(X_train, y_train).predict(X_test)
y_hat_lasso = model_lasso.fit(X_train, y_train).predict(X_test)
y_hat_net   = model_net.fit(X_train, y_train).predict(X_test)

# %%
df_predictions = pd.DataFrame({'y_test':y_test,
                               'y_hat_linear':y_hat_linear,
                               'y_hat_ridge':y_hat_ridge,
                               'y_hat_lasso':y_hat_lasso,
                               'y_hat_net':y_hat_net})
df_predictions.head()
# Out:
#       y_test  y_hat_linear  y_hat_ridge  y_hat_lasso  y_hat_net
# 88  1.307243      0.171067     0.171067     0.171067   0.171067
# 4  -0.404102     -0.079686    -0.079686    -0.079686  -0.079686
# 62 -1.055680     -0.180921    -0.180921    -0.180921  -0.180921
# 63  2.538916      2.344482     2.344482     2.344482   2.344482
# 48  1.144605     -0.078630    -0.078630    -0.078630  -0.078630

# %% [markdown]
# ### coefficients

# %%
df.drop('y', axis=1, inplace=False).columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5'], dtype='object')

# %%
coefficients = pd.DataFrame({'Features':df.drop('y', axis=1, inplace=False).columns})
coefficients['model_lin']= model_linear.coef_
coefficients['model_ridge']= model_ridge.coef_
coefficients['model_lasso']= model_lasso.coef_
coefficients['model_net']= model_net.coef_
coefficients
# Out:
#   Features  model_lin  model_ridge  model_lasso  model_net
# 0       X1   0.537047     0.537047     0.537047   0.537047
# 1       X2   0.103655     0.103655     0.103655   0.103655
# 2       X3  -2.133872    -2.133872    -2.133872  -2.133872
# 3       X4   0.253492     0.253492     0.253492   0.253492
# 4       X5   1.593336     1.593336     1.593336   1.593336

# %% [markdown]
# Exercise: Why do you think if $\alpha = 0$, all the 4 model coefficients are the same?

# %% [markdown]
# ----

# %% [markdown]
# ### Performance in the test set

# %%
model_linear.score(X_test, y_test)
# Out:
# -0.505175889658485

# %%
MSE_test_lin = np.mean(np.square(df_predictions['y_test'] - df_predictions['y_hat_linear']))
RMSE_test_lin = np.sqrt(MSE_test_lin)
np.round(RMSE_test_lin,3)
# Out:
# 2.037

# %%
model_ridge.score(X_test, y_test)
# Out:
# -0.5051758896588487

# %%
MSE_test_ridge = np.mean(np.square(df_predictions['y_test'] - df_predictions['y_hat_ridge']))
RMSE_test_ridge = np.sqrt(MSE_test_ridge)
np.round(RMSE_test_ridge,3)
# Out:
# 2.037

# %%
model_lasso.score(X_test, y_test)
# Out:
# -0.5051758639724002

# %%
MSE_test_lasso = np.mean(np.square(df_predictions['y_test'] - df_predictions['y_hat_lasso']))
RMSE_test_lasso = np.sqrt(MSE_test_lasso)
np.round(RMSE_test_lasso,3)
# Out:
# 2.037

# %%
model_net.score(X_test, y_test)
# Out:
# -0.5051758639724002

# %%
MSE_test_net = np.mean(np.square(df_predictions['y_test'] - df_predictions['y_hat_net']))
RMSE_test_net = np.sqrt(MSE_test_net)
np.round(RMSE_test_net,3)
# Out:
# 2.037

# %% [markdown]
# -------------

# %% [markdown]
# ### Plotting the regression coefficients vs alphas:

# %% [markdown]
# #### 1) Ridge regression coefficients vs alpha

# %%
alpha_ridge = 10**np.linspace(-3,4,100)
plt.figure(figsize=(12,5))
plt.plot(alpha_ridge,'or' )
plt.xlabel('steps')
plt.ylabel('alpha (lambda)')
plt.show()

# %%
len(alpha_ridge)
# Out:
# 100

# %%
ridge = Ridge()
coefs_ridge = []

for i in alpha_ridge:
    ridge.set_params(alpha = i)
    ridge.fit(X_train, y_train)
    coefs_ridge.append(ridge.coef_)
    
np.shape(coefs_ridge)
# Out:
# (100, 5)

# %%
plt.figure(figsize=(10,6))
ax = plt.gca()
ax.plot(alpha_ridge, coefs_ridge)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights: scaled coefficients')
plt.title('Ridge regression coefficients Vs. alpha')
plt.legend(df.drop('y',axis=1, inplace=False).columns)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### 2) Lasso regression coefficients vs alpha

# %%
alpha_lasso = 10**np.linspace(-3,1,100)

# %%
lasso = Lasso()
coefs_lasso = []

for i in alpha_lasso:
    lasso.set_params(alpha = i)
    lasso.fit(X_train, y_train)
    coefs_lasso.append(lasso.coef_)
    
np.shape(coefs_lasso)
# Out:
# (100, 5)

# %%
plt.figure(figsize=(10,6))
ax = plt.gca()
ax.plot(alpha_lasso, coefs_lasso)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights: scaled coefficients')
plt.title('Lasso regression coefficients Vs. alpha')
plt.legend(df.drop('y',axis=1, inplace=False).columns)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### 3) Elastic Net regression coefficients vs alpha

# %%
alpha_elasticnet = 10**np.linspace(-3,1,100)

# %%
elasticnet = ElasticNet()
coefs_elasticnet = []

for i in alpha_elasticnet:
    elasticnet.set_params(alpha = i)
    elasticnet.fit(X_train, y_train)
    coefs_elasticnet.append(elasticnet.coef_)
    
np.shape(coefs_elasticnet)
# Out:
# (100, 5)

# %%
plt.figure(figsize=(12,10))
ax = plt.gca()
ax.plot(alpha_elasticnet, coefs_elasticnet)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights: scaled coefficients')
plt.title('Elastic Net regression coefficients Vs. alpha')
plt.legend(df.drop('y',axis=1, inplace=False).columns)

plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## Cross Validation
#
# Let's use cross validation to find the optimal Lambdas (alphas) for different models.

# %% [markdown]
# #### 1) Optimal alpha for Ridge regression

# %%
ridgecv = RidgeCV(alphas=alpha_ridge)
ridgecv.fit(X_train, y_train)
ridgecv.alpha_
# Out:
# 1.291549665014884

# %%
alpha_ridge_opt = ridgecv.alpha_

# %% [markdown]
# ----

# %% [markdown]
# #### 2) Optimal alpha for Lasso regression

# %%
lassocv = LassoCV(alphas=alpha_lasso)
lassocv.fit(X_train, y_train)
lassocv.alpha_
# Out:
# 0.004862601580065354

# %%
alpha_lasso_opt = lassocv.alpha_

# %% [markdown]
# ----

# %% [markdown]
# #### 3) Optimal alpha for Elastic Net regression

# %%
elasticnetcv = ElasticNetCV(alphas=alpha_elasticnet)
elasticnetcv.fit(X_train, y_train)
elasticnetcv.alpha_
# Out:
# 0.006428073117284319

# %%
elasticnetcv.l1_ratio_
# Out:
# 0.5

# %%
alpha_elasticnet_opt = elasticnetcv.alpha_

# %% [markdown]
# ----

# %% [markdown]
# #### Refit the models!
#
# ***Exercise***: Now go back and refit the 3 models with the optimal alphas!
# - compare the RMSE_test?
# - were you able to beat the linear regression model?
# - what do you conclude?

# %% [markdown]
# ---
# ---
# # PyCaret
#
# 1. **PyCaret**: https://pycaret.readthedocs.io/en/latest/index.html PyCaret3.0
# 2. **scikit-learn**: https://scikit-learn.org/stable/index.html
# 3. **PyCaret model containers** : https://github.com/pycaret/pycaret/tree/master/pycaret/containers/models

# %% [markdown]
# # Installation

# %% [markdown]
# Follow the steps here: https://pycaret.gitbook.io/docs/get-started/installation

# %%
#only if you want to run it in Google Colab: 
# for this chapter, we can install the light version of PyCaret as below. 

# !pip install --pre pycaret

# %%
# if you got a warning that you need to "RESTART RUNTIME", go ahead and press that button. 

# let's double ckeck the Pycaret version: 
from pycaret.utils import version
version()
# Out:
# '3.0.0.rc4'

# %%
df.head()
# Out:
#          X1        X2        X3        X4         X5          y
# 0  1.668068  2.782452  4.641320  7.742038  12.914249  -3.901562
# 1  0.925862  0.857220  0.793667  0.734826   0.680348  -0.384578
# 2  1.057997  1.119357  1.184276  1.252960   1.325628  12.493677
# 3 -0.920339  0.847024 -0.779549  0.717449  -0.660297  12.237389
# 4  1.299748  1.689346  2.195725  2.853890   3.709339  -3.772851

# %%
from pycaret.regression import *

# %%
setup(df, target='y', session_id=1000, train_size=0.8, fold_strategy='kfold', fold=5, 
      normalize=True, normalize_method='zscore')
# Out:
# <style type="text/css">
# #T_2c173_row7_col1, #T_2c173_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c173">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c173_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2c173_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c173_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c173_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2c173_row0_col1" class="data row0 col1" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c173_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2c173_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c173_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2c173_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c173_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_2c173_row3_col1" class="data row3 col1" >(100, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c173_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_2c173_row4_col1" class="data row4 col1" >(80, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c173_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_2c173_row5_col1" class="data row5 col1" >(20, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c173_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_2c173_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c173_row7_col0" class="data row7 col0" >Preprocess</td>
#       <td id="T_2c173_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c173_row8_col0" class="data row8 col0" >Imputation type</td>
#       <td id="T_2c173_row8_col1" class="data row8 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c173_row9_col0" class="data row9 col0" >Numeric imputation</td>
#       <td id="T_2c173_row9_col1" class="data row9 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c173_row10_col0" class="data row10 col0" >Categorical imputation</td>
#       <td id="T_2c173_row10_col1" class="data row10 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c173_row11_col0" class="data row11 col0" >Low variance threshold</td>
#       <td id="T_2c173_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2c173_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_2c173_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2c173_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_2c173_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2c173_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_2c173_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2c173_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_2c173_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2c173_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_2c173_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2c173_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_2c173_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2c173_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_2c173_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2c173_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_2c173_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2c173_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2c173_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_2c173_row20_col1" class="data row20 col1" >1a55</td>
#     </tr>
#   </tbody>
# </table>

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# catboost                 CatBoost Regressor
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# catboost                    catboost.core.CatBoostRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %% [markdown]
# ## Create and tune model

# %%
lr = create_model(estimator='lr')
# Out:
# <style type="text/css">
# #T_088b7_row5_col0, #T_088b7_row5_col1, #T_088b7_row5_col2, #T_088b7_row5_col3, #T_088b7_row5_col4, #T_088b7_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_088b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_088b7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_088b7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_088b7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_088b7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_088b7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_088b7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_088b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_088b7_row0_col0" class="data row0 col0" >7.0868</td>
#       <td id="T_088b7_row0_col1" class="data row0 col1" >69.3051</td>
#       <td id="T_088b7_row0_col2" class="data row0 col2" >8.3250</td>
#       <td id="T_088b7_row0_col3" class="data row0 col3" >0.0811</td>
#       <td id="T_088b7_row0_col4" class="data row0 col4" >1.1554</td>
#       <td id="T_088b7_row0_col5" class="data row0 col5" >2.2193</td>
#     </tr>
#     <tr>
#       <th id="T_088b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_088b7_row1_col0" class="data row1 col0" >8.1472</td>
#       <td id="T_088b7_row1_col1" class="data row1 col1" >138.2158</td>
#       <td id="T_088b7_row1_col2" class="data row1 col2" >11.7565</td>
#       <td id="T_088b7_row1_col3" class="data row1 col3" >-0.3866</td>
#       <td id="T_088b7_row1_col4" class="data row1 col4" >1.0653</td>
#       <td id="T_088b7_row1_col5" class="data row1 col5" >1.3712</td>
#     </tr>
#     <tr>
#       <th id="T_088b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_088b7_row2_col0" class="data row2 col0" >10.9808</td>
#       <td id="T_088b7_row2_col1" class="data row2 col1" >313.8018</td>
#       <td id="T_088b7_row2_col2" class="data row2 col2" >17.7145</td>
#       <td id="T_088b7_row2_col3" class="data row2 col3" >-0.0065</td>
#       <td id="T_088b7_row2_col4" class="data row2 col4" >1.5855</td>
#       <td id="T_088b7_row2_col5" class="data row2 col5" >0.7485</td>
#     </tr>
#     <tr>
#       <th id="T_088b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_088b7_row3_col0" class="data row3 col0" >10.7973</td>
#       <td id="T_088b7_row3_col1" class="data row3 col1" >199.8801</td>
#       <td id="T_088b7_row3_col2" class="data row3 col2" >14.1379</td>
#       <td id="T_088b7_row3_col3" class="data row3 col3" >-0.1573</td>
#       <td id="T_088b7_row3_col4" class="data row3 col4" >1.2084</td>
#       <td id="T_088b7_row3_col5" class="data row3 col5" >0.9093</td>
#     </tr>
#     <tr>
#       <th id="T_088b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_088b7_row4_col0" class="data row4 col0" >5.4064</td>
#       <td id="T_088b7_row4_col1" class="data row4 col1" >45.4753</td>
#       <td id="T_088b7_row4_col2" class="data row4 col2" >6.7435</td>
#       <td id="T_088b7_row4_col3" class="data row4 col3" >0.5687</td>
#       <td id="T_088b7_row4_col4" class="data row4 col4" >1.0221</td>
#       <td id="T_088b7_row4_col5" class="data row4 col5" >2.4226</td>
#     </tr>
#     <tr>
#       <th id="T_088b7_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_088b7_row5_col0" class="data row5 col0" >8.4837</td>
#       <td id="T_088b7_row5_col1" class="data row5 col1" >153.3356</td>
#       <td id="T_088b7_row5_col2" class="data row5 col2" >11.7355</td>
#       <td id="T_088b7_row5_col3" class="data row5 col3" >0.0199</td>
#       <td id="T_088b7_row5_col4" class="data row5 col4" >1.2073</td>
#       <td id="T_088b7_row5_col5" class="data row5 col5" >1.5342</td>
#     </tr>
#     <tr>
#       <th id="T_088b7_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_088b7_row6_col0" class="data row6 col0" >2.1505</td>
#       <td id="T_088b7_row6_col1" class="data row6 col1" >96.7878</td>
#       <td id="T_088b7_row6_col2" class="data row6 col2" >3.9515</td>
#       <td id="T_088b7_row6_col3" class="data row6 col3" >0.3170</td>
#       <td id="T_088b7_row6_col4" class="data row6 col4" >0.2001</td>
#       <td id="T_088b7_row6_col5" class="data row6 col5" >0.6772</td>
#     </tr>
#   </tbody>
# </table>

# %%
#tuned_lr = tune_model(lr) # we really don't need to run this line. Why?

# %%
lasso = create_model(estimator='lasso')
# Out:
# <style type="text/css">
# #T_fe819_row5_col0, #T_fe819_row5_col1, #T_fe819_row5_col2, #T_fe819_row5_col3, #T_fe819_row5_col4, #T_fe819_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fe819">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe819_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fe819_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fe819_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fe819_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fe819_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fe819_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe819_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe819_row0_col0" class="data row0 col0" >6.8909</td>
#       <td id="T_fe819_row0_col1" class="data row0 col1" >72.4029</td>
#       <td id="T_fe819_row0_col2" class="data row0 col2" >8.5090</td>
#       <td id="T_fe819_row0_col3" class="data row0 col3" >0.0401</td>
#       <td id="T_fe819_row0_col4" class="data row0 col4" >1.0412</td>
#       <td id="T_fe819_row0_col5" class="data row0 col5" >1.4003</td>
#     </tr>
#     <tr>
#       <th id="T_fe819_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe819_row1_col0" class="data row1 col0" >8.2973</td>
#       <td id="T_fe819_row1_col1" class="data row1 col1" >120.1616</td>
#       <td id="T_fe819_row1_col2" class="data row1 col2" >10.9618</td>
#       <td id="T_fe819_row1_col3" class="data row1 col3" >-0.2055</td>
#       <td id="T_fe819_row1_col4" class="data row1 col4" >0.9738</td>
#       <td id="T_fe819_row1_col5" class="data row1 col5" >1.1786</td>
#     </tr>
#     <tr>
#       <th id="T_fe819_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe819_row2_col0" class="data row2 col0" >9.4402</td>
#       <td id="T_fe819_row2_col1" class="data row2 col1" >113.3639</td>
#       <td id="T_fe819_row2_col2" class="data row2 col2" >10.6472</td>
#       <td id="T_fe819_row2_col3" class="data row2 col3" >0.6364</td>
#       <td id="T_fe819_row2_col4" class="data row2 col4" >1.1718</td>
#       <td id="T_fe819_row2_col5" class="data row2 col5" >1.0820</td>
#     </tr>
#     <tr>
#       <th id="T_fe819_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe819_row3_col0" class="data row3 col0" >10.9375</td>
#       <td id="T_fe819_row3_col1" class="data row3 col1" >189.1648</td>
#       <td id="T_fe819_row3_col2" class="data row3 col2" >13.7537</td>
#       <td id="T_fe819_row3_col3" class="data row3 col3" >-0.0952</td>
#       <td id="T_fe819_row3_col4" class="data row3 col4" >1.2808</td>
#       <td id="T_fe819_row3_col5" class="data row3 col5" >0.9071</td>
#     </tr>
#     <tr>
#       <th id="T_fe819_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe819_row4_col0" class="data row4 col0" >5.9705</td>
#       <td id="T_fe819_row4_col1" class="data row4 col1" >57.2171</td>
#       <td id="T_fe819_row4_col2" class="data row4 col2" >7.5642</td>
#       <td id="T_fe819_row4_col3" class="data row4 col3" >0.4574</td>
#       <td id="T_fe819_row4_col4" class="data row4 col4" >0.7774</td>
#       <td id="T_fe819_row4_col5" class="data row4 col5" >1.4978</td>
#     </tr>
#     <tr>
#       <th id="T_fe819_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_fe819_row5_col0" class="data row5 col0" >8.3073</td>
#       <td id="T_fe819_row5_col1" class="data row5 col1" >110.4621</td>
#       <td id="T_fe819_row5_col2" class="data row5 col2" >10.2872</td>
#       <td id="T_fe819_row5_col3" class="data row5 col3" >0.1666</td>
#       <td id="T_fe819_row5_col4" class="data row5 col4" >1.0490</td>
#       <td id="T_fe819_row5_col5" class="data row5 col5" >1.2132</td>
#     </tr>
#     <tr>
#       <th id="T_fe819_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_fe819_row6_col0" class="data row6 col0" >1.7702</td>
#       <td id="T_fe819_row6_col1" class="data row6 col1" >46.0003</td>
#       <td id="T_fe819_row6_col2" class="data row6 col2" >2.1531</td>
#       <td id="T_fe819_row6_col3" class="data row6 col3" >0.3251</td>
#       <td id="T_fe819_row6_col4" class="data row6 col4" >0.1722</td>
#       <td id="T_fe819_row6_col5" class="data row6 col5" >0.2136</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# What is happening inside the tune_model? https://github.com/pycaret/pycaret/blob/master/pycaret/containers/models/regression.py

# %%
tuned_lasso = tune_model(lasso)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   10:39:01
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .           Lasso Regression
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
ridge = create_model(estimator='ridge')
# Out:
# <style type="text/css">
# #T_1995d_row5_col0, #T_1995d_row5_col1, #T_1995d_row5_col2, #T_1995d_row5_col3, #T_1995d_row5_col4, #T_1995d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1995d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1995d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1995d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1995d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1995d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1995d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1995d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1995d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1995d_row0_col0" class="data row0 col0" >7.1222</td>
#       <td id="T_1995d_row0_col1" class="data row0 col1" >71.5477</td>
#       <td id="T_1995d_row0_col2" class="data row0 col2" >8.4586</td>
#       <td id="T_1995d_row0_col3" class="data row0 col3" >0.0514</td>
#       <td id="T_1995d_row0_col4" class="data row0 col4" >1.1987</td>
#       <td id="T_1995d_row0_col5" class="data row0 col5" >2.0879</td>
#     </tr>
#     <tr>
#       <th id="T_1995d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1995d_row1_col0" class="data row1 col0" >7.9911</td>
#       <td id="T_1995d_row1_col1" class="data row1 col1" >125.7941</td>
#       <td id="T_1995d_row1_col2" class="data row1 col2" >11.2158</td>
#       <td id="T_1995d_row1_col3" class="data row1 col3" >-0.2620</td>
#       <td id="T_1995d_row1_col4" class="data row1 col4" >0.9757</td>
#       <td id="T_1995d_row1_col5" class="data row1 col5" >1.2352</td>
#     </tr>
#     <tr>
#       <th id="T_1995d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1995d_row2_col0" class="data row2 col0" >8.0989</td>
#       <td id="T_1995d_row2_col1" class="data row2 col1" >88.5367</td>
#       <td id="T_1995d_row2_col2" class="data row2 col2" >9.4094</td>
#       <td id="T_1995d_row2_col3" class="data row2 col3" >0.7160</td>
#       <td id="T_1995d_row2_col4" class="data row2 col4" >1.4172</td>
#       <td id="T_1995d_row2_col5" class="data row2 col5" >0.7952</td>
#     </tr>
#     <tr>
#       <th id="T_1995d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1995d_row3_col0" class="data row3 col0" >10.9981</td>
#       <td id="T_1995d_row3_col1" class="data row3 col1" >193.6841</td>
#       <td id="T_1995d_row3_col2" class="data row3 col2" >13.9170</td>
#       <td id="T_1995d_row3_col3" class="data row3 col3" >-0.1214</td>
#       <td id="T_1995d_row3_col4" class="data row3 col4" >1.3644</td>
#       <td id="T_1995d_row3_col5" class="data row3 col5" >0.9450</td>
#     </tr>
#     <tr>
#       <th id="T_1995d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1995d_row4_col0" class="data row4 col0" >5.4602</td>
#       <td id="T_1995d_row4_col1" class="data row4 col1" >48.5251</td>
#       <td id="T_1995d_row4_col2" class="data row4 col2" >6.9660</td>
#       <td id="T_1995d_row4_col3" class="data row4 col3" >0.5398</td>
#       <td id="T_1995d_row4_col4" class="data row4 col4" >1.0812</td>
#       <td id="T_1995d_row4_col5" class="data row4 col5" >2.1170</td>
#     </tr>
#     <tr>
#       <th id="T_1995d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_1995d_row5_col0" class="data row5 col0" >7.9341</td>
#       <td id="T_1995d_row5_col1" class="data row5 col1" >105.6175</td>
#       <td id="T_1995d_row5_col2" class="data row5 col2" >9.9934</td>
#       <td id="T_1995d_row5_col3" class="data row5 col3" >0.1848</td>
#       <td id="T_1995d_row5_col4" class="data row5 col4" >1.2075</td>
#       <td id="T_1995d_row5_col5" class="data row5 col5" >1.4360</td>
#     </tr>
#     <tr>
#       <th id="T_1995d_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_1995d_row6_col0" class="data row6 col0" >1.7999</td>
#       <td id="T_1995d_row6_col1" class="data row6 col1" >50.7442</td>
#       <td id="T_1995d_row6_col2" class="data row6 col2" >2.3980</td>
#       <td id="T_1995d_row6_col3" class="data row6 col3" >0.3793</td>
#       <td id="T_1995d_row6_col4" class="data row6 col4" >0.1663</td>
#       <td id="T_1995d_row6_col5" class="data row6 col5" >0.5623</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_ridge = tune_model(ridge)
# Out:
# <style type="text/css">
# #T_d0ba8_row5_col0, #T_d0ba8_row5_col1, #T_d0ba8_row5_col2, #T_d0ba8_row5_col3, #T_d0ba8_row5_col4, #T_d0ba8_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d0ba8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0ba8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d0ba8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d0ba8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d0ba8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d0ba8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d0ba8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0ba8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0ba8_row0_col0" class="data row0 col0" >7.0373</td>
#       <td id="T_d0ba8_row0_col1" class="data row0 col1" >73.2329</td>
#       <td id="T_d0ba8_row0_col2" class="data row0 col2" >8.5576</td>
#       <td id="T_d0ba8_row0_col3" class="data row0 col3" >0.0291</td>
#       <td id="T_d0ba8_row0_col4" class="data row0 col4" >1.1522</td>
#       <td id="T_d0ba8_row0_col5" class="data row0 col5" >1.6162</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0ba8_row1_col0" class="data row1 col0" >7.6992</td>
#       <td id="T_d0ba8_row1_col1" class="data row1 col1" >108.6549</td>
#       <td id="T_d0ba8_row1_col2" class="data row1 col2" >10.4238</td>
#       <td id="T_d0ba8_row1_col3" class="data row1 col3" >-0.0901</td>
#       <td id="T_d0ba8_row1_col4" class="data row1 col4" >0.9175</td>
#       <td id="T_d0ba8_row1_col5" class="data row1 col5" >1.0665</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0ba8_row2_col0" class="data row2 col0" >8.8156</td>
#       <td id="T_d0ba8_row2_col1" class="data row2 col1" >102.0067</td>
#       <td id="T_d0ba8_row2_col2" class="data row2 col2" >10.0998</td>
#       <td id="T_d0ba8_row2_col3" class="data row2 col3" >0.6728</td>
#       <td id="T_d0ba8_row2_col4" class="data row2 col4" >1.2371</td>
#       <td id="T_d0ba8_row2_col5" class="data row2 col5" >0.9387</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0ba8_row3_col0" class="data row3 col0" >11.0324</td>
#       <td id="T_d0ba8_row3_col1" class="data row3 col1" >188.0422</td>
#       <td id="T_d0ba8_row3_col2" class="data row3 col2" >13.7128</td>
#       <td id="T_d0ba8_row3_col3" class="data row3 col3" >-0.0887</td>
#       <td id="T_d0ba8_row3_col4" class="data row3 col4" >1.3650</td>
#       <td id="T_d0ba8_row3_col5" class="data row3 col5" >0.9106</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0ba8_row4_col0" class="data row4 col0" >5.6979</td>
#       <td id="T_d0ba8_row4_col1" class="data row4 col1" >50.9092</td>
#       <td id="T_d0ba8_row4_col2" class="data row4 col2" >7.1351</td>
#       <td id="T_d0ba8_row4_col3" class="data row4 col3" >0.5172</td>
#       <td id="T_d0ba8_row4_col4" class="data row4 col4" >0.9073</td>
#       <td id="T_d0ba8_row4_col5" class="data row4 col5" >1.6538</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d0ba8_row5_col0" class="data row5 col0" >8.0565</td>
#       <td id="T_d0ba8_row5_col1" class="data row5 col1" >104.5692</td>
#       <td id="T_d0ba8_row5_col2" class="data row5 col2" >9.9858</td>
#       <td id="T_d0ba8_row5_col3" class="data row5 col3" >0.2081</td>
#       <td id="T_d0ba8_row5_col4" class="data row5 col4" >1.1158</td>
#       <td id="T_d0ba8_row5_col5" class="data row5 col5" >1.2372</td>
#     </tr>
#     <tr>
#       <th id="T_d0ba8_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d0ba8_row6_col0" class="data row6 col0" >1.7979</td>
#       <td id="T_d0ba8_row6_col1" class="data row6 col1" >46.5883</td>
#       <td id="T_d0ba8_row6_col2" class="data row6 col2" >2.2028</td>
#       <td id="T_d0ba8_row6_col3" class="data row6 col3" >0.3227</td>
#       <td id="T_d0ba8_row6_col4" class="data row6 col4" >0.1794</td>
#       <td id="T_d0ba8_row6_col5" class="data row6 col5" >0.3293</td>
#     </tr>
#   </tbody>
# </table>

# %%
elasticnet = create_model(estimator='en')
# Out:
# <style type="text/css">
# #T_7e436_row5_col0, #T_7e436_row5_col1, #T_7e436_row5_col2, #T_7e436_row5_col3, #T_7e436_row5_col4, #T_7e436_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7e436">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e436_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7e436_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7e436_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7e436_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7e436_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7e436_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e436_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e436_row0_col0" class="data row0 col0" >6.8438</td>
#       <td id="T_7e436_row0_col1" class="data row0 col1" >72.7915</td>
#       <td id="T_7e436_row0_col2" class="data row0 col2" >8.5318</td>
#       <td id="T_7e436_row0_col3" class="data row0 col3" >0.0349</td>
#       <td id="T_7e436_row0_col4" class="data row0 col4" >1.0098</td>
#       <td id="T_7e436_row0_col5" class="data row0 col5" >1.2854</td>
#     </tr>
#     <tr>
#       <th id="T_7e436_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e436_row1_col0" class="data row1 col0" >7.7426</td>
#       <td id="T_7e436_row1_col1" class="data row1 col1" >110.7061</td>
#       <td id="T_7e436_row1_col2" class="data row1 col2" >10.5217</td>
#       <td id="T_7e436_row1_col3" class="data row1 col3" >-0.1106</td>
#       <td id="T_7e436_row1_col4" class="data row1 col4" >0.9257</td>
#       <td id="T_7e436_row1_col5" class="data row1 col5" >1.0901</td>
#     </tr>
#     <tr>
#       <th id="T_7e436_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e436_row2_col0" class="data row2 col0" >10.1275</td>
#       <td id="T_7e436_row2_col1" class="data row2 col1" >128.6768</td>
#       <td id="T_7e436_row2_col2" class="data row2 col2" >11.3436</td>
#       <td id="T_7e436_row2_col3" class="data row2 col3" >0.5873</td>
#       <td id="T_7e436_row2_col4" class="data row2 col4" >1.2022</td>
#       <td id="T_7e436_row2_col5" class="data row2 col5" >1.0975</td>
#     </tr>
#     <tr>
#       <th id="T_7e436_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e436_row3_col0" class="data row3 col0" >11.0100</td>
#       <td id="T_7e436_row3_col1" class="data row3 col1" >185.7460</td>
#       <td id="T_7e436_row3_col2" class="data row3 col2" >13.6289</td>
#       <td id="T_7e436_row3_col3" class="data row3 col3" >-0.0754</td>
#       <td id="T_7e436_row3_col4" class="data row3 col4" >1.2077</td>
#       <td id="T_7e436_row3_col5" class="data row3 col5" >0.9298</td>
#     </tr>
#     <tr>
#       <th id="T_7e436_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e436_row4_col0" class="data row4 col0" >5.8872</td>
#       <td id="T_7e436_row4_col1" class="data row4 col1" >51.9317</td>
#       <td id="T_7e436_row4_col2" class="data row4 col2" >7.2064</td>
#       <td id="T_7e436_row4_col3" class="data row4 col3" >0.5075</td>
#       <td id="T_7e436_row4_col4" class="data row4 col4" >0.8650</td>
#       <td id="T_7e436_row4_col5" class="data row4 col5" >1.4571</td>
#     </tr>
#     <tr>
#       <th id="T_7e436_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_7e436_row5_col0" class="data row5 col0" >8.3222</td>
#       <td id="T_7e436_row5_col1" class="data row5 col1" >109.9704</td>
#       <td id="T_7e436_row5_col2" class="data row5 col2" >10.2465</td>
#       <td id="T_7e436_row5_col3" class="data row5 col3" >0.1887</td>
#       <td id="T_7e436_row5_col4" class="data row5 col4" >1.0421</td>
#       <td id="T_7e436_row5_col5" class="data row5 col5" >1.1720</td>
#     </tr>
#     <tr>
#       <th id="T_7e436_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_7e436_row6_col0" class="data row6 col0" >1.9460</td>
#       <td id="T_7e436_row6_col1" class="data row6 col1" >46.5686</td>
#       <td id="T_7e436_row6_col2" class="data row6 col2" >2.2317</td>
#       <td id="T_7e436_row6_col3" class="data row6 col3" >0.2978</td>
#       <td id="T_7e436_row6_col4" class="data row6 col4" >0.1407</td>
#       <td id="T_7e436_row6_col5" class="data row6 col5" >0.1817</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_elasticnet = tune_model(elasticnet)
# Out:
# <style type="text/css">
# #T_e5d0e_row5_col0, #T_e5d0e_row5_col1, #T_e5d0e_row5_col2, #T_e5d0e_row5_col3, #T_e5d0e_row5_col4, #T_e5d0e_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e5d0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5d0e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e5d0e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e5d0e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e5d0e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e5d0e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e5d0e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5d0e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5d0e_row0_col0" class="data row0 col0" >6.8442</td>
#       <td id="T_e5d0e_row0_col1" class="data row0 col1" >73.8503</td>
#       <td id="T_e5d0e_row0_col2" class="data row0 col2" >8.5936</td>
#       <td id="T_e5d0e_row0_col3" class="data row0 col3" >0.0209</td>
#       <td id="T_e5d0e_row0_col4" class="data row0 col4" >0.8843</td>
#       <td id="T_e5d0e_row0_col5" class="data row0 col5" >1.3688</td>
#     </tr>
#     <tr>
#       <th id="T_e5d0e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5d0e_row1_col0" class="data row1 col0" >8.2204</td>
#       <td id="T_e5d0e_row1_col1" class="data row1 col1" >115.8774</td>
#       <td id="T_e5d0e_row1_col2" class="data row1 col2" >10.7646</td>
#       <td id="T_e5d0e_row1_col3" class="data row1 col3" >-0.1625</td>
#       <td id="T_e5d0e_row1_col4" class="data row1 col4" >0.8878</td>
#       <td id="T_e5d0e_row1_col5" class="data row1 col5" >1.2525</td>
#     </tr>
#     <tr>
#       <th id="T_e5d0e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5d0e_row2_col0" class="data row2 col0" >11.8028</td>
#       <td id="T_e5d0e_row2_col1" class="data row2 col1" >201.7555</td>
#       <td id="T_e5d0e_row2_col2" class="data row2 col2" >14.2041</td>
#       <td id="T_e5d0e_row2_col3" class="data row2 col3" >0.3529</td>
#       <td id="T_e5d0e_row2_col4" class="data row2 col4" >1.1872</td>
#       <td id="T_e5d0e_row2_col5" class="data row2 col5" >1.1445</td>
#     </tr>
#     <tr>
#       <th id="T_e5d0e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5d0e_row3_col0" class="data row3 col0" >10.9716</td>
#       <td id="T_e5d0e_row3_col1" class="data row3 col1" >180.7471</td>
#       <td id="T_e5d0e_row3_col2" class="data row3 col2" >13.4442</td>
#       <td id="T_e5d0e_row3_col3" class="data row3 col3" >-0.0465</td>
#       <td id="T_e5d0e_row3_col4" class="data row3 col4" >1.0806</td>
#       <td id="T_e5d0e_row3_col5" class="data row3 col5" >0.9643</td>
#     </tr>
#     <tr>
#       <th id="T_e5d0e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e5d0e_row4_col0" class="data row4 col0" >6.4776</td>
#       <td id="T_e5d0e_row4_col1" class="data row4 col1" >65.6927</td>
#       <td id="T_e5d0e_row4_col2" class="data row4 col2" >8.1051</td>
#       <td id="T_e5d0e_row4_col3" class="data row4 col3" >0.3770</td>
#       <td id="T_e5d0e_row4_col4" class="data row4 col4" >0.7860</td>
#       <td id="T_e5d0e_row4_col5" class="data row4 col5" >1.6138</td>
#     </tr>
#     <tr>
#       <th id="T_e5d0e_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_e5d0e_row5_col0" class="data row5 col0" >8.8633</td>
#       <td id="T_e5d0e_row5_col1" class="data row5 col1" >127.5846</td>
#       <td id="T_e5d0e_row5_col2" class="data row5 col2" >11.0223</td>
#       <td id="T_e5d0e_row5_col3" class="data row5 col3" >0.1083</td>
#       <td id="T_e5d0e_row5_col4" class="data row5 col4" >0.9652</td>
#       <td id="T_e5d0e_row5_col5" class="data row5 col5" >1.2688</td>
#     </tr>
#     <tr>
#       <th id="T_e5d0e_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_e5d0e_row6_col0" class="data row6 col0" >2.1572</td>
#       <td id="T_e5d0e_row6_col1" class="data row6 col1" >55.1046</td>
#       <td id="T_e5d0e_row6_col2" class="data row6 col2" >2.4684</td>
#       <td id="T_e5d0e_row6_col3" class="data row6 col3" >0.2177</td>
#       <td id="T_e5d0e_row6_col4" class="data row6 col4" >0.1465</td>
#       <td id="T_e5d0e_row6_col5" class="data row6 col5" >0.2179</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models([lr,tuned_lr, lasso, tuned_lasso, ridge, tuned_ridge, elasticnet, tuned_elasticnet])
# Out:
# <style type="text/css">
# #T_fe813 th {
#   text-align: left;
# }
# #T_fe813_row0_col0, #T_fe813_row0_col1, #T_fe813_row0_col5, #T_fe813_row0_col6, #T_fe813_row1_col0, #T_fe813_row1_col1, #T_fe813_row1_col2, #T_fe813_row1_col3, #T_fe813_row1_col4, #T_fe813_row2_col0, #T_fe813_row2_col1, #T_fe813_row2_col2, #T_fe813_row2_col3, #T_fe813_row2_col4, #T_fe813_row3_col0, #T_fe813_row3_col2, #T_fe813_row3_col3, #T_fe813_row3_col4, #T_fe813_row3_col5, #T_fe813_row3_col6, #T_fe813_row4_col0, #T_fe813_row4_col1, #T_fe813_row4_col2, #T_fe813_row4_col3, #T_fe813_row4_col4, #T_fe813_row4_col5, #T_fe813_row4_col6, #T_fe813_row5_col0, #T_fe813_row5_col1, #T_fe813_row5_col2, #T_fe813_row5_col3, #T_fe813_row5_col4, #T_fe813_row5_col5, #T_fe813_row5_col6, #T_fe813_row6_col0, #T_fe813_row6_col1, #T_fe813_row6_col2, #T_fe813_row6_col3, #T_fe813_row6_col4, #T_fe813_row6_col5, #T_fe813_row6_col6, #T_fe813_row7_col0, #T_fe813_row7_col1, #T_fe813_row7_col2, #T_fe813_row7_col3, #T_fe813_row7_col4, #T_fe813_row7_col5, #T_fe813_row7_col6 {
#   text-align: left;
# }
# #T_fe813_row0_col2, #T_fe813_row0_col3, #T_fe813_row0_col4, #T_fe813_row1_col5, #T_fe813_row1_col6, #T_fe813_row2_col5, #T_fe813_row2_col6, #T_fe813_row3_col1 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_fe813_row0_col7, #T_fe813_row1_col7, #T_fe813_row2_col7, #T_fe813_row3_col7, #T_fe813_row4_col7, #T_fe813_row5_col7, #T_fe813_row6_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_fe813_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_fe813">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe813_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fe813_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fe813_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fe813_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fe813_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fe813_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fe813_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_fe813_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe813_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_fe813_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_fe813_row0_col1" class="data row0 col1" >8.0565</td>
#       <td id="T_fe813_row0_col2" class="data row0 col2" >104.5692</td>
#       <td id="T_fe813_row0_col3" class="data row0 col3" >9.9858</td>
#       <td id="T_fe813_row0_col4" class="data row0 col4" >0.2081</td>
#       <td id="T_fe813_row0_col5" class="data row0 col5" >1.1158</td>
#       <td id="T_fe813_row0_col6" class="data row0 col6" >1.2372</td>
#       <td id="T_fe813_row0_col7" class="data row0 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_fe813_row1_col0" class="data row1 col0" >Elastic Net</td>
#       <td id="T_fe813_row1_col1" class="data row1 col1" >8.3222</td>
#       <td id="T_fe813_row1_col2" class="data row1 col2" >109.9704</td>
#       <td id="T_fe813_row1_col3" class="data row1 col3" >10.2465</td>
#       <td id="T_fe813_row1_col4" class="data row1 col4" >0.1887</td>
#       <td id="T_fe813_row1_col5" class="data row1 col5" >1.0421</td>
#       <td id="T_fe813_row1_col6" class="data row1 col6" >1.1720</td>
#       <td id="T_fe813_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_fe813_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_fe813_row2_col1" class="data row2 col1" >8.3222</td>
#       <td id="T_fe813_row2_col2" class="data row2 col2" >109.9704</td>
#       <td id="T_fe813_row2_col3" class="data row2 col3" >10.2465</td>
#       <td id="T_fe813_row2_col4" class="data row2 col4" >0.1887</td>
#       <td id="T_fe813_row2_col5" class="data row2 col5" >1.0421</td>
#       <td id="T_fe813_row2_col6" class="data row2 col6" >1.1720</td>
#       <td id="T_fe813_row2_col7" class="data row2 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fe813_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_fe813_row3_col1" class="data row3 col1" >7.9341</td>
#       <td id="T_fe813_row3_col2" class="data row3 col2" >105.6175</td>
#       <td id="T_fe813_row3_col3" class="data row3 col3" >9.9934</td>
#       <td id="T_fe813_row3_col4" class="data row3 col4" >0.1848</td>
#       <td id="T_fe813_row3_col5" class="data row3 col5" >1.2075</td>
#       <td id="T_fe813_row3_col6" class="data row3 col6" >1.4360</td>
#       <td id="T_fe813_row3_col7" class="data row3 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_fe813_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_fe813_row4_col1" class="data row4 col1" >8.3073</td>
#       <td id="T_fe813_row4_col2" class="data row4 col2" >110.4621</td>
#       <td id="T_fe813_row4_col3" class="data row4 col3" >10.2872</td>
#       <td id="T_fe813_row4_col4" class="data row4 col4" >0.1666</td>
#       <td id="T_fe813_row4_col5" class="data row4 col5" >1.0490</td>
#       <td id="T_fe813_row4_col6" class="data row4 col6" >1.2132</td>
#       <td id="T_fe813_row4_col7" class="data row4 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_fe813_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_fe813_row5_col1" class="data row5 col1" >8.3073</td>
#       <td id="T_fe813_row5_col2" class="data row5 col2" >110.4621</td>
#       <td id="T_fe813_row5_col3" class="data row5 col3" >10.2872</td>
#       <td id="T_fe813_row5_col4" class="data row5 col4" >0.1666</td>
#       <td id="T_fe813_row5_col5" class="data row5 col5" >1.0490</td>
#       <td id="T_fe813_row5_col6" class="data row5 col6" >1.2132</td>
#       <td id="T_fe813_row5_col7" class="data row5 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_fe813_row6_col0" class="data row6 col0" >Linear Regression</td>
#       <td id="T_fe813_row6_col1" class="data row6 col1" >8.4837</td>
#       <td id="T_fe813_row6_col2" class="data row6 col2" >153.3356</td>
#       <td id="T_fe813_row6_col3" class="data row6 col3" >11.7355</td>
#       <td id="T_fe813_row6_col4" class="data row6 col4" >0.0199</td>
#       <td id="T_fe813_row6_col5" class="data row6 col5" >1.2073</td>
#       <td id="T_fe813_row6_col6" class="data row6 col6" >1.5342</td>
#       <td id="T_fe813_row6_col7" class="data row6 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_fe813_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_fe813_row7_col0" class="data row7 col0" >Linear Regression</td>
#       <td id="T_fe813_row7_col1" class="data row7 col1" >8.4837</td>
#       <td id="T_fe813_row7_col2" class="data row7 col2" >153.3356</td>
#       <td id="T_fe813_row7_col3" class="data row7 col3" >11.7355</td>
#       <td id="T_fe813_row7_col4" class="data row7 col4" >0.0199</td>
#       <td id="T_fe813_row7_col5" class="data row7 col5" >1.2073</td>
#       <td id="T_fe813_row7_col6" class="data row7 col6" >1.5342</td>
#       <td id="T_fe813_row7_col7" class="data row7 col7" >0.0140</td>
#     </tr>
#   </tbody>
# </table>
# Ridge(alpha=8.8, normalize=False, random_state=1000)

# %% [markdown]
# The best model is tuned ridge!

# %% [markdown]
# Bonus question: Why we were not able to get the same answer with PyCaret? remember, our best model was ElasticNet.

# %% [markdown]
# ## Plot model

# %%
plot_model(tuned_ridge,plot='residuals')

# %%
plot_model(tuned_ridge,plot='error' )

# %%
plot_model(tuned_ridge,plot='learning')

# %% [markdown]
# ## Predict model

# %%
pycaret_predictions = predict_model(tuned_ridge)
pycaret_predictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8bbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8bbc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f8bbc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f8bbc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f8bbc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f8bbc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f8bbc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f8bbc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8bbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8bbc_row0_col0" class="data row0 col0" >Ridge Regression</td>
#       <td id="T_f8bbc_row0_col1" class="data row0 col1" >13.5487</td>
#       <td id="T_f8bbc_row0_col2" class="data row0 col2" >340.7346</td>
#       <td id="T_f8bbc_row0_col3" class="data row0 col3" >18.4590</td>
#       <td id="T_f8bbc_row0_col4" class="data row0 col4" >0.5805</td>
#       <td id="T_f8bbc_row0_col5" class="data row0 col5" >1.3176</td>
#       <td id="T_f8bbc_row0_col6" class="data row0 col6" >0.8507</td>
#     </tr>
#   </tbody>
# </table>
#           X1        X2         X3         X4         X5          y  \
# 80 -1.342994  0.653944  -0.728806   0.119711  -0.166146  25.602488
# 81  1.366072  0.723884   0.911710   0.169741   0.408039  -3.772851
# 82 -0.189839 -0.796612   0.060925  -0.396861   0.104370 -14.957215
# 83 -2.294512  3.503153  -3.901068   4.028481  -3.858919  46.744209
# 84 -1.125647  0.212730  -0.402390  -0.142618  -0.007192  22.810785
# 85  1.228628  0.428716   0.681080  -0.025692   0.283380  15.660195
# 86 -1.174062  0.304265  -0.465305  -0.095756  -0.033446 -10.956726
# 87 -1.059094  0.093217  -0.324353  -0.197845   0.022210   3.248486
# 88 -0.732303 -0.387569  -0.064357  -0.351835   0.091509  14.289402
# 89 -0.128545 -0.812297   0.062403  -0.397014   0.104382  11.126081
# 90  3.610241  9.953098  15.640549  27.046227  38.887714 -96.615135
# 91 -0.018355 -0.824906   0.063038  -0.397052   0.104384 -15.068184
# 92 -0.055133 -0.822925   0.062995  -0.397051   0.104384 -17.751352
# 93  0.582815 -0.540859   0.129742  -0.377970   0.108763   9.201485
# 94 -0.614025 -0.518151  -0.011817  -0.374799   0.099077  -2.255177
# 95 -2.363592  3.768176  -4.270677   4.587036  -4.493757  38.355419
# 96 -0.948003 -0.089994  -0.214410  -0.269404   0.057273  -8.139212
# 97 -0.219333 -0.786855   0.059749  -0.396707   0.104355 -15.849248
# 98  0.100093 -0.816115   0.063412  -0.397033   0.104385   2.179013
# 99  0.167428 -0.800797   0.064704  -0.396913   0.104393  14.121992
#
#     prediction_label
# 80          6.240702
# 81          2.257370
# 82          1.153878
# 83         37.089645
# 84          3.734337
# 85          2.892073
# 86          4.201828
# 87          3.167159
# 88          1.437668
# 89          1.246520
# 90       -158.125778
# 91          1.452103
# 92          1.378512
# 93          2.906642
# 94          1.157198
# 95         41.281719
# 96          2.397420
# 97          1.115739
# 98          1.716089
# 99          1.879973

# %% [markdown]
# ----

# %% [markdown]
# ###  Additional links:
# 1. Underfitting vs Overfitting: https://scikit-learn.org/stable/auto_examples/model_selection/plot_underfitting_overfitting.html#sphx-glr-auto-examples-model-selection-plot-underfitting-overfitting-py
# 2. From Linear Regression to Ridge Regression, the Lasso, and the Elastic Net: https://towardsdatascience.com/from-linear-regression-to-ridge-regression-the-lasso-and-the-elastic-net-4eaecaf5f7e6
# 3. Standardizing features in Python:https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# 4. sklearn Ridge: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html
# 5. sklearn RidgeCV: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeCV.html#sklearn.linear_model.RidgeCV
# 6. sklearn Lasso: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html
# 7. skearn LassoCV: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html#sklearn.linear_model.LassoCV
# 8. sklearn Elasticnet: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html
# 9. sklearn ElasticNetCV: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNetCV.html#sklearn.linear_model.ElasticNetCV
