# %% [markdown]
# # Prof. Pedram Jahangiry
#
# You need to make a copy to your own Google drive if you want to edit the original notebook! Start by opening this notebook on Colab 👇
#
# <a href="https://colab.research.google.com/github/PJalgotrader/Machine_Learning-USU/blob/main/Lectures%20and%20codes/Module%2011-%20PCA/python/PCA_pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# ![logo](https://upload.wikimedia.org/wikipedia/commons/4/44/Huntsman-Wordmark-with-USU-Blue.gif#center)
#
#
# ## 🔗 Links
#
# [![linkedin](https://img.shields.io/badge/LinkedIn-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pedram-jahangiry-cfa-5778015a)
#
# [![Youtube](https://img.shields.io/badge/youtube_channel-1DA1F2?style=for-the-badge&logo=youtube&logoColor=white&color=FF0000)](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ)
#
# [![Twitter URL](https://img.shields.io/twitter/url/https/twitter.com/PedramJahangiry.svg?style=social&label=Follow%20%40PedramJahangiry)](https://twitter.com/PedramJahangiry)
#
#
# ---

# %% [markdown]
# # Unsupervised Learning: Principle Component Analysis (PCA)
#
# ## Using pca package
# pca is a python package to perform Principal Component Analysis and to create insightful plots. The core of PCA is build on **sklearn** functionality to find maximum compatibility when combining with other packages.
#
# for **installation**:
# pip install pca

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  #if you want to use seaborn themes with matplotlib functions
import warnings
warnings.filterwarnings('ignore')

# %%
rand_state= 1000

# %%
# to install the pca package, you need to run "pip install pca" first. On Google colab, do 
# !pip install pca
from pca import pca

# %%
pca()

# %%
usarrest = pd.read_csv('https://raw.githubusercontent.com/PJalgotrader/Machine_Learning-USU/main/data/USArrests.csv')
usarrest.head()
# Out:
#         state  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
X= usarrest.drop('state', axis=1) # scaling the features will be automatically done. 
states = usarrest.state

# %%
model=pca(n_components=4, normalize=True)

# %%
results = model.fit_transform(X)
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed on the [4] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[4]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %%
results
# Out:
# {'loadings':        Murder   Assault  UrbanPop      Rape
#  PC1  0.535899  0.583184  0.278191  0.543432
#  PC2  0.418181  0.187986 -0.872806 -0.167319
#  PC3 -0.341233 -0.268148 -0.378016  0.817778
#  PC4  0.649228 -0.743407  0.133878  0.089024,
#  'PC':          PC1       PC2       PC3       PC4
#  0   0.985566  1.133392 -0.444269  0.156267
#  1   1.950138  1.073213  2.040003 -0.438583
#  2   1.763164 -0.745957  0.054781 -0.834653
#  3  -0.141420  1.119797  0.114574 -0.182811
#  4   2.523980 -1.542934  0.598557 -0.341996
#  5   1.514563 -0.987555  1.095007  0.001465
#  6  -1.358647 -1.088928 -0.643258 -0.118469
#  7   0.047709 -0.325359 -0.718633 -0.881978
#  8   3.013042  0.039229 -0.576829 -0.096285
#  9   1.639283  1.278942 -0.342460  1.076797
#  10 -0.912657 -1.570460  0.050782  0.902807
#  11 -1.639800  0.210973  0.259801 -0.499104
#  12  1.378911 -0.681841 -0.677496 -0.122021
#  13 -0.505461 -0.151563  0.228055  0.424666
#  14 -2.253646 -0.104054  0.164564  0.017556
#  15 -0.796881 -0.270165  0.025553  0.206496
#  16 -0.750859  0.958440 -0.028369  0.670557
#  17  1.564818  0.871055 -0.783480  0.454728
#  18 -2.396829  0.376392 -0.065682 -0.330460
#  19  1.763369  0.427655 -0.157250 -0.559070
#  20 -0.486166 -1.474496 -0.609497 -0.179599
#  21  2.108441 -0.155397  0.384869  0.102372
#  22 -1.692682 -0.632261  0.153070  0.067317
#  23  0.996494  2.393796 -0.740808  0.215508
#  24  0.696787 -0.263355  0.377444  0.225824
#  25 -1.185452  0.536874  0.246889  0.123742
#  26 -1.265637 -0.193954  0.175574  0.015893
#  27  2.874395 -0.775600  1.163380  0.314515
#  28 -2.383915 -0.018082  0.036855 -0.033137
#  29  0.181566 -1.449506 -0.764454  0.243383
#  30  1.980024  0.142849  0.183692 -0.339534
#  31  1.682577 -0.823184 -0.643075 -0.013484
#  32  1.123379  2.228003 -0.863572 -0.954382
#  33 -2.992226  0.599119  0.301277 -0.253987
#  34 -0.225965 -0.742238 -0.031139  0.473916
#  35 -0.311783 -0.287854 -0.015310  0.010332
#  36  0.059122 -0.541411  0.939833 -0.237781
#  37 -0.888416 -0.571100 -0.400629  0.359061
#  38 -0.863772 -1.491978 -1.369946 -0.613569
#  39  1.320724  1.933405 -0.300538 -0.131467
#  40 -1.987775  0.823343  0.389293 -0.109572
#  41  0.999742  0.860251  0.188083  0.652864
#  42  1.355138 -0.412481 -0.492069  0.643195
#  43 -0.550565 -1.471505  0.293728 -0.082314
#  44 -2.801412  1.402288  0.841263 -0.144890
#  45 -0.096335  0.199735  0.011713  0.211371
#  46 -0.216903 -0.970124  0.624871 -0.220848
#  47 -2.108585  1.424847  0.104775  0.131909
#  48 -2.079714 -0.611269 -0.138865  0.184104
#  49 -0.629427  0.321013 -0.240659 -0.166652,
#  'explained_var': array([0.62006039, 0.86750168, 0.95664248, 1.        ]),
#  'variance_ratio': array([0.62006039, 0.24744129, 0.0891408 , 0.04335752]),
#  'model': PCA(n_components=4),
#  'scaler': StandardScaler(),
#  'pcp': 1.0,
#  'topfeat':     PC   feature   loading  type
#  0  PC1   Assault  0.583184  best
#  1  PC2  UrbanPop -0.872806  best
#  2  PC3      Rape  0.817778  best
#  3  PC4   Assault -0.743407  best
#  4  PC4    Murder  0.649228  weak,
#  'outliers':      y_proba     p_raw    y_score  y_bool  y_bool_spe  y_score_spe
# %%
loadings=results['loadings']
loadings.T
# Out:
#                PC1       PC2       PC3       PC4
# Murder    0.535899  0.418181 -0.341233  0.649228
# Assault   0.583184  0.187986 -0.268148 -0.743407
# UrbanPop  0.278191 -0.872806 -0.378016  0.133878
# Rape      0.543432 -0.167319  0.817778  0.089024

# %%
scores=results['PC']
scores['lables']=states
scores.head()
# Out:
#         PC1       PC2       PC3       PC4      lables
# 0  0.985566  1.133392 -0.444269  0.156267     Alabama
# 1  1.950138  1.073213  2.040003 -0.438583      Alaska
# 2  1.763164 -0.745957  0.054781 -0.834653     Arizona
# 3 -0.141420  1.119797  0.114574 -0.182811    Arkansas
# 4  2.523980 -1.542934  0.598557 -0.341996  California

# %% [markdown]
# ---
# ## Scree plot

# %%
model.plot(figsize=(10,8))
plt.show()

# %% [markdown]
# ---
# ## Biplot
#
# Biplot displays both the PC scores and PC loadings. We will use the **pca.biplot_** method from the **pca** library.

# %%
model.biplot(n_feat=4 , legend=False, figsize=(16,12), y=states , label=True)
plt.show()
# Out:
# [pca] >Plot PC1 vs PC2 with loadings.
# [colourmap]> Warning: Colormap [Set1] can not create [50] unique colors! Available unique colors: [9].
# [colourmap]> Warning: Colormap [Set1] can not create [50] unique colors! Available unique colors: [9].

# %%
loadings.T.iloc[:, range(2)]
# Out:
#                PC1       PC2
# Murder    0.535899  0.418181
# Assault   0.583184  0.187986
# UrbanPop  0.278191 -0.872806
# Rape      0.543432 -0.167319

# %% [markdown]
# ---
# ## PCA application: Market Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/PJalgotrader/Machine_Learning-USU/main/data/market_data.csv')

# %%
df.head()
# Out:
#    stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0        72  1/31/2018          0.86         0.85         0.86
# 1        78  1/31/2018          0.66         0.67         0.66
# 2       465  1/31/2018          0.57         0.65         0.64
# 3       486  1/31/2018          0.48         0.52         0.50
# 4       552  1/31/2018          0.88         0.87         0.87
#
#    Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  Total_Capital  \
# 0            0.90    0.84  0.01         0.17         0.09  ...           0.54
# 1            0.37    0.92  0.01         0.25         0.58  ...           0.27
# 2            0.71    0.18  0.01         0.35         0.46  ...           0.18
# 3            0.36    0.30  0.01         0.81         0.81  ...           0.70
# 4            0.88    0.75  0.01         0.81         0.77  ...           0.64
#
#    Total_Debt  Total_Debt_Capital  Total_Liabilities_Total_Assets  Vol1Y_Usd  \
# 0        0.85                1.00                            0.99       0.22
# 1        0.65                1.00                            1.00       0.04
# 2        0.61                1.00                            1.00       0.99
# 3        0.85                0.99                            0.99       0.96
# 4        0.81                0.99                            0.99       0.92
#
#    Vol3Y_Usd  R1M_Usd  R3M_Usd  R6M_Usd  R12M_Usd
# 0       0.83   -0.022   -0.078    0.001     0.000
# 1       0.17    0.006    0.047    0.264     0.000
# 2       1.00    0.033    0.095    0.393    -0.502
# 3       0.98   -0.139    0.146    0.030    -0.463
# 4       0.74   -0.044   -0.307   -0.349    -0.403
#
# [5 rows x 99 columns]

# %%
df.shape
# Out:
# (4451, 99)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 
#  60  Ocf                             4451 non-null   float64
#  61  Ocf_Bv                          4451 non-null   float64
#  62  Ocf_Ce                          4451 non-null   float64
#  63  Ocf_Margin                      4451 non-null   float64
#  64  Ocf_Noa                         4451 non-null   float64
#  65  Ocf_Oa                          4451 non-null   float64
#  66  Ocf_Ta                          4451 non-null   float64
#  67  Ocf_Tbv                         4451 non-null   float64
#  68  Ocf_Toa                         4451 non-null   float64
#  69  Op_Margin                       4451 non-null   float64
#  70  Op_Prt_Margin                   4451 non-null   float64
#  71  Oper_Ps_Net_Cf                  4451 non-null   float64
#  72  Pb                              4451 non-null   float64
#  73  Pe                              4451 non-null   float64
#  74  Ptx_Mgn                         4451 non-null   float64
#  75  Recurring_Earning_Total_Assets  4451 non-null   float64
#  76  Return_On_Capital               4451 non-null   float64
#  77  Rev                             4451 non-null   float64
#  78  Roa                             4451 non-null   float64
#  79  Roc                             4451 non-null   float64
#  80  Roce                            4451 non-null   float64
#  81  Roe                             4451 non-null   float64
#  82  Sales_Ps                        4451 non-null   float64
#  83  Share_Turn_12M                  4450 non-null   float64
#  84  Share_Turn_3M                   4450 non-null   float64
#  85  Share_Turn_6M                   4450 non-null   float64
#  86  Ta                              4450 non-null   float64
#  87  Tev_Less_Mktcap                 4450 non-null   float64
#  88  Tot_Debt_Rev                    4450 non-null   float64
#  89  Total_Capital                   4450 non-null   float64
#  90  Total_Debt                      4450 non-null   float64
#  91  Total_Debt_Capital              4450 non-null   float64
#  92  Total_Liabilities_Total_Assets  4450 non-null   float64
#  93  Vol1Y_Usd                       4450 non-null   float64
#  94  Vol3Y_Usd                       4450 non-null   float64
#  95  R1M_Usd                         4450 non-null   float64
#  96  R3M_Usd                         4450 non-null   float64
#  97  R6M_Usd                         4450 non-null   float64
#  98  R12M_Usd                        4450 non-null   float64
# dtypes: float64(97), int64(1), object(1)
# memory usage: 3.4+ MB

# %%
df.dropna(inplace=True)

# %%
X= df.drop(['stock_id','date'], axis=1) # scaling the features will be automatically done.

# %%
model=pca(n_components=0.8, normalize=True)

# %%
results = model.fit_transform(X)
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed to capture [80.0%] explained variance using the [97] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [14] that covers the [80.00%] explained variance.
# [pca] >The PCA reduction is performed on the [97] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[14]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %%
#results

# %%
loadings=results['loadings']
loadings
# Out:
#       Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  Asset_Turnover    Bb_Yld  \
# PC1       0.123418     0.126343     0.125503        0.020272  0.063947
# PC2       0.138670     0.130818     0.133819       -0.044864  0.013430
# PC3      -0.124841    -0.124347    -0.125028       -0.270337 -0.046424
# PC4       0.020009     0.016622     0.017209       -0.084316 -0.015866
# PC5      -0.145089    -0.163348    -0.157988        0.090045  0.002189
# PC6       0.078594     0.058830     0.066675        0.109736  0.078342
# PC7      -0.037808    -0.025146    -0.031071        0.105944  0.045151
# PC8       0.001212     0.015463     0.008946        0.016331  0.012732
# PC9      -0.020203    -0.028523    -0.025599        0.010087  0.044469
# PC10     -0.121696    -0.109011    -0.112914        0.135625 -0.103742
# PC11      0.062044     0.072971     0.068469       -0.019970 -0.018708
# PC12      0.050440     0.037580     0.044356       -0.019125 -0.013255
# PC13      0.022383     0.029401     0.026318       -0.022546  0.042363
# PC14     -0.020581    -0.029245    -0.027235        0.012683  0.040905
#
#             Bv  Capex_Ps_Cf  Capex_Sales  Cash_Div_Cf  Cash_Per_Share  ...  \
# PC1   0.011040     0.041722     0.022285     0.035080        0.127626  ...
# PC2  -0.048430     0.090063     0.068790    -0.033752       -0.044533  ...
# PC3   0.049457    -0.097445     0.015554     0.120505       -0.022217  ...
# PC4  -0.075285    -0.164699    -0.102310     0.012749        0.153057  ...
# PC5   0.083527     0.180400    -0.036946     0.076480        0.087071  ...
# PC6  -0.162630    -0.188042    -0.178748     0.150650       -0.115773  ...
# PC7   0.007345     0.043082    -0.093853     0.196788        0.041983  ...
# PC8  -0.056523    -0.073942    -0.215970    -0.059571        0.182987  ...
# PC9  -0.103830     0.065239     0.061256     0.080189       -0.029348  ...
# PC10 -0.239469    -0.178355    -0.163533     0.118551       -0.148085  ...
# PC11  0.101534    -0.074625    -0.101567     0.282294       -0.177742  ...
# PC12  0.267139    -0.226604    -0.323858    -0.077266        0.107296  ...
# PC13 -0.054485     0.080309     0.115182    -0.053982       -0.012190  ...
# PC14  0.106175     0.108430     0.247947    -0.060665       -0.137155  ...
#
#       Total_Capital  Total_Debt  Total_Debt_Capital  \
# PC1        0.076032    0.070140            0.043927
# PC2        0.222852    0.240883            0.213707
# PC3        0.036238    0.033167            0.033519
# PC4        0.026350    0.043163            0.049611
# PC5        0.027945    0.024661            0.041025
# PC6       -0.043349   -0.010270           -0.013387
# PC7        0.016152    0.004649           -0.005759
# PC8        0.020477    0.028992           -0.036939
# PC9        0.021318    0.038677            0.009645
# PC10      -0.006968    0.077920            0.172017
# PC11       0.062783    0.014431           -0.067057
# PC12       0.085743   -0.017028           -0.099779
# PC13      -0.082557   -0.037400            0.029701
# PC14       0.139177    0.032315           -0.144831
#
#       Total_Liabilities_Total_Assets  Vol1Y_Usd  Vol3Y_Usd   R1M_Usd  \
# PC1                         0.045840  -0.090418  -0.095654 -0.004191
# PC2                         0.195219   0.020990   0.015851  0.004126
# PC3                         0.085877  -0.167333  -0.165144  0.005037
# PC4                         0.050243   0.063363   0.064438  0.044356
# PC5                         0.070705   0.025710   0.003051  0.039454
# PC6                         0.063171   0.000765  -0.022200 -0.023874
# PC7                         0.013813  -0.242937  -0.256067 -0.018137
# PC8                         0.042459   0.010193   0.037241 -0.020531
# PC9                        -0.113269  -0.097302  -0.096602  0.107674
# PC10                        0.130648   0.019990   0.056947  0.039498
# PC11                       -0.038839   0.052716   0.012294  0.102438
# PC12                       -0.102560  -0.056935  -0.043775  0.109517
# PC13                        0.047368   0.008432   0.015041  0.464615
# PC14                       -0.076560  -0.066775  -0.020439  0.020978
#
#        R3M_Usd   R6M_Usd  R12M_Usd
# PC1  -0.006775 -0.004689 -0.001792
# PC2   0.007243  0.007869  0.001106
# PC3   0.009049  0.018022  0.019287
# PC4   0.065483  0.081798  0.055318
# PC5   0.059146  0.066366  0.042993
# PC6  -0.026809 -0.023409 -0.018305
# PC7  -0.019321 -0.001715  0.015591
# PC8  -0.023922 -0.035573 -0.039172
# PC9   0.134668  0.159653  0.108825
# PC10  0.047917  0.051496  0.036196
# PC11  0.124679  0.146126  0.059910
# PC12  0.124918  0.123608  0.032885
# PC13  0.506481  0.481067  0.108936
# PC14  0.013009  0.031283  0.045431
#
# [14 rows x 97 columns]

# %%
scores=results['PC']
scores.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  6.363602  6.173358 -2.505719 -0.046888 -3.548422  3.646388  3.239559
# 1  9.523135  2.507746  1.660610  0.326092 -5.300236  0.318351 -1.242024
# 2  5.800236  1.898347 -2.195352  1.877717 -2.937161 -0.332760 -3.459275
# 3  0.715543  9.557593 -0.380253  3.213804 -1.973094 -3.231277 -0.846973
# 4  9.303851  7.762789 -2.299555 -0.555051 -0.338316  3.320722  0.365953
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14
# 0  3.767995  0.813620  0.403473  1.583797  0.762704 -0.921196  0.122031
# 1  1.599831  2.907919 -1.443255 -1.287795 -1.231103  0.402848 -2.630097
# 2  3.265755  1.186446  1.896000 -0.379309 -1.993772  0.449148 -0.234289
# 3  2.958357  0.090786  0.506885 -0.244402 -1.157871 -0.713828  2.488687
# 4  2.617630  1.731020 -0.664728  2.326303 -3.205116 -0.588561  0.850946

# %%
scores.shape
# Out:
# (4450, 14)

# %% [markdown]
# ---
# ## Scree plot

# %%
model.plot(figsize=(10,8))
plt.show()

# %%
labels= np.array(list(itertools.repeat("No label", len(X))))
model.biplot(n_feat=3,  legend=False, figsize=(16,12), y= labels, label=False, cmap=None)
plt.show()
# Out:
# [pca] >Plot PC1 vs PC2 with loadings.

# %% [markdown]
# ---
# ###  Additional links:
# 1. pca Python package documentation: https://pypi.org/project/pca/
# 2. PCA sklearn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
# 3. PCA visualization: https://setosa.io/ev/principal-component-analysis/
# 4. Kernel PCA sklearn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.KernelPCA.html#sklearn.decomposition.KernelPCA
# 5. Kernel PCA visualization: https://scikit-learn.org/stable/auto_examples/decomposition/plot_kernel_pca.html#sphx-glr-auto-examples-decomposition-plot-kernel-pca-py
# 6. What is Singular Value Decomposition (SVD): https://www.youtube.com/watch?v=mBcLRGuAFUk
