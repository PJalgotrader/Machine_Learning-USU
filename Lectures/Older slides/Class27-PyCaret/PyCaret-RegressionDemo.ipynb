# %% [markdown]
# ## Prof. Pedram Jahangiry
#
# You need to make a copy to your own Google drive if you want to edit the original notebook! Start by opening this notebook on Colab 👇
#
# <a href="https://colab.research.google.com/github/PJalgotrader/Machine_Learning-USU/blob/fall22/Lectures/Class27-PyCaret/PyCaret-RegressionDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
#
# ![logo](https://upload.wikimedia.org/wikipedia/commons/4/44/Huntsman-Wordmark-with-USU-Blue.gif#center)
#
#
#
# ## 🔗 Links
# [![Youtube](https://img.shields.io/badge/youtube_channel-1DA1F2?style=for-the-badge&logo=youtube&logoColor=white&color=red)](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ)
# [![Profile](https://img.shields.io/badge/profiole-000?style=for-the-badge&logo=ko-fi&logoColor=white)](https://huntsman.usu.edu/directory/jahangiry-pedram)
# [![linkedin](https://img.shields.io/badge/linkedin-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pedram-jahangiry-cfa-5778015a)
#
# ---

# %% [markdown]
# Source:
# 1. https://nbviewer.org/github/pycaret/pycaret/blob/master/tutorials/Regression%20Tutorial%20Level%20Beginner%20-%20REG101.ipynb
# 2. https://nbviewer.org/github/pycaret/pycaret/blob/master/tutorials/Regression%20Tutorial%20Level%20Intermediate%20-%20REG102.ipynb
# 3. https://pycaret.gitbook.io/docs/get-started/quickstart#regression
# 4. https://pycaret.readthedocs.io/en/stable/api/regression.html PyCaret2.0
# 5. https://pycaret.readthedocs.io/en/latest/index.html PyCaret3.0
# 6. https://towardsdatascience.com/pycaret-3-0-is-coming-soon-whats-new-e890e6a69ff5

# %% [markdown]
# # How to do Regression with PyCaret
#
# PyCaret's Regression module (pycaret.regression) is a supervised machine learning module which is used for predicting continuous values / outcomes using various techniques and algorithms. Regression can be used for predicting values / outcomes such as sales, units sold, temperature or any number which is continuous.
#
# PyCaret's regression module has over 25 algorithms and 10 plots to analyze the performance of models. Be it hyper-parameter tuning, ensembling or advanced techniques like stacking, PyCaret's regression module has it all.
#
# In this notebook, we will explore:
#
#
# * **Getting Data**: How to import data from PyCaret dataset
# * **Normalization**: How to normalize and scale the dataset
# * **Transformation**: How to apply transformations that make the data linear and approximately normal
# * **Target Transformation**: How to apply transformations to the target variable
# * **Ignore Low Variance**: How to remove features with statistically insignificant variances to make the experiment more efficient
# * **Remove Multi-collinearity**: How to remove multi-collinearity from the dataset to boost performance of Linear algorithms
# * **Group Features**: How to extract statistical information from related features in the dataset
# * **Combine Rare Levels**: How to combine rare levels in categorical features
# * **Bin Numeric Variables**: How to bin numeric variables and transform numeric features into categorical ones using 'sturges' rule
# * **Setting up Environment**: How to setup an experiment in PyCaret and get started with building regression models
# * **Create Model**: How to create a model, perform cross validation and evaluate regression metrics
# * **Tune Model**: How to automatically tune the hyperparameters of a regression model
# * **Plot Model**: How to analyze model performance using various plots
# * **Finalize Model**: How to finalize the best model at the end of the experiment
# * **Predict Model**: How to make prediction on new / unseen data
# * **Model Ensembling and Stacking**: How to boost model performance using several ensembling techniques such as Bagging, Boosting, Soft/hard Voting and Generalized Stacking
# * **Save / Load Model**: How to save / load a model for future use
# * **Experiment Logging**: How to log experiments in PyCaret using MLFlow backend

# %% [markdown]
# # Installation

# %% [markdown]
# Follow the steps here: https://pycaret.gitbook.io/docs/get-started/installation

# %%
#only if you want to run it in Google Colab: 

# !pip install --pre pycaret[full]

# %%
# let's double ckeck the Pycaret version: 
from pycaret.utils import version
version()
# Out:
# '3.0.0.rc4'

# %% [markdown]
# # Importing Dataset

# %%
from pycaret.datasets import get_data

#here is the list of all available datasets
all_datasets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
dataset = get_data('bike')
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  cnt
# 0           1  0.24  0.2879  0.81        0.0   16
# 1           1  0.22  0.2727  0.80        0.0   40
# 2           1  0.22  0.2727  0.80        0.0   32
# 3           1  0.24  0.2879  0.75        0.0   13
# 4           1  0.24  0.2879  0.75        0.0    1

# %%
# dataset = get_data('bike', profile=True) # profile=True is going to do an automated EDA, you need to "pip install pycaret[analysis]" first.

# %%
# for the sake of time, lets work with a tiny subsample of the data, 
dataset = dataset.sample(1000)

# %%
data = dataset.sample(frac=0.9, random_state=123)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (900, 15)
# Unseen Data For Predictions: (100, 15)

# %%
data.shape
# Out:
# (900, 15)

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0     6679  10/10/2011       4   0    10  20        1        1           0
# 1    16223  11/13/2012       4   1    11  16        0        2           1
# 2     5233   8/10/2011       3   0     8  22        0        3           1
# 3     3902   6/16/2011       2   0     6  11        0        4           1
# 4     9993   2/26/2012       1   1     2   9        0        0           0
#
#    weathersit  temp   atemp   hum  windspeed  cnt
# 0           1  0.60  0.5909  0.73     0.0000  225
# 1           1  0.38  0.3939  0.40     0.2985  310
# 2           1  0.74  0.6515  0.37     0.0000  139
# 3           2  0.68  0.6364  0.61     0.2985  150
# 4           1  0.22  0.2121  0.47     0.2239   87

# %%
data.nunique()
# Out:
# instant       900
# dteday        517
# season          4
# yr              2
# mnth           12
# hr             24
# holiday         2
# weekday         7
# workingday      2
# weathersit      4
# temp           45
# atemp          56
# hum            73
# windspeed      24
# cnt           403
# dtype: int64

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
categoricals = ['season', 'yr', 'mnth', 'hr','holiday', 'weekday','workingday','weathersit' ]
numericals   = ['temp', 'atemp', 'hum', 'windspeed']
ignore       = ['instant','dteday']

# %% [markdown]
# ## Setting up Environment in PyCaret
#
# **setup()**:
#
# This function initializes the training environment and creates the transformation pipeline. Setup function must be called before executing any other function. It takes two mandatory parameters: data and target. All the other parameters are optional.

# %%
from pycaret.regression import *

# %% [markdown]
# The latest version of PyCaret is Object oriented API. This means that the settings are linked with an object, you can run as many experiments as you want in the same notebook and compare them seamlessly not just across different modeling options but also different preprocessing settings.

# %%
# experience1 = no preprocessing
exp1 = RegressionExperiment() 
exp1.setup(data, ignore_features=ignore,  target='cnt', session_id=555, train_size=0.7, preprocess=False, categorical_features= categoricals, numeric_features=numericals)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d50c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d50c8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d50c8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d50c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d50c8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d50c8_row0_col1" class="data row0 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d50c8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d50c8_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d50c8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d50c8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d50c8_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_d50c8_row3_col1" class="data row3 col1" >(900, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d50c8_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_d50c8_row4_col1" class="data row4 col1" >(629, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d50c8_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_d50c8_row5_col1" class="data row5 col1" >(271, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d50c8_row6_col0" class="data row6 col0" >Ignore features</td>
#       <td id="T_d50c8_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d50c8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d50c8_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d50c8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d50c8_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_d50c8_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# experiment 2, with preprocessing and more!!!
exp2 = RegressionExperiment() 
exp2.setup(data, ignore_features=ignore, target='cnt', session_id=555, train_size=0.7, categorical_features= categoricals, numeric_features=numericals, numeric_imputation='mean', categorical_imputation='mode' ,
           preprocess=True, normalize=True , remove_outliers=True, ordinal_features=None)
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# <style type="text/css">
# #T_dc07e_row10_col1, #T_dc07e_row17_col1, #T_dc07e_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dc07e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc07e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dc07e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc07e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc07e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dc07e_row0_col1" class="data row0 col1" >555</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc07e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dc07e_row1_col1" class="data row1 col1" >cnt</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dc07e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dc07e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dc07e_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_dc07e_row3_col1" class="data row3 col1" >(874, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dc07e_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_dc07e_row4_col1" class="data row4 col1" >(603, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dc07e_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_dc07e_row5_col1" class="data row5 col1" >(271, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dc07e_row6_col0" class="data row6 col0" >Ignore features</td>
#       <td id="T_dc07e_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dc07e_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_dc07e_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dc07e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_dc07e_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dc07e_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_dc07e_row9_col1" class="data row9 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dc07e_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_dc07e_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dc07e_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_dc07e_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dc07e_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_dc07e_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dc07e_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_dc07e_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dc07e_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_dc07e_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dc07e_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_dc07e_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dc07e_row16_col0" class="data row16 col0" >Low variance threshold</td>
#       <td id="T_dc07e_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dc07e_row17_col0" class="data row17 col0" >Remove outliers</td>
#       <td id="T_dc07e_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dc07e_row18_col0" class="data row18 col0" >Outliers threshold</td>
#       <td id="T_dc07e_row18_col1" class="data row18 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dc07e_row19_col0" class="data row19 col0" >Normalize</td>
#       <td id="T_dc07e_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dc07e_row20_col0" class="data row20 col0" >Normalize method</td>
#       <td id="T_dc07e_row20_col1" class="data row20 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_dc07e_row21_col0" class="data row21 col0" >Fold Generator</td>
#       <td id="T_dc07e_row21_col1" class="data row21 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_dc07e_row22_col0" class="data row22 col0" >Fold Number</td>
#       <td id="T_dc07e_row22_col1" class="data row22 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_dc07e_row23_col0" class="data row23 col0" >CPU Jobs</td>
#       <td id="T_dc07e_row23_col1" class="data row23 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_dc07e_row24_col0" class="data row24 col0" >Use GPU</td>
#       <td id="T_dc07e_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_dc07e_row25_col0" class="data row25 col0" >Log Experiment</td>
#       <td id="T_dc07e_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_dc07e_row26_col0" class="data row26 col0" >Experiment Name</td>
#       <td id="T_dc07e_row26_col1" class="data row26 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dc07e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_dc07e_row27_col0" class="data row27 col0" >USI</td>
#       <td id="T_dc07e_row27_col1" class="data row27 col1" >bb6d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Compare Models
#
# This function trains and evaluates performance of all estimators available in the model library using cross validation. The output of this function is a score grid with average cross validated scores. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function.

# %%
top3_exp1 = exp1.compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_7d25e th {
#   text-align: left;
# }
# #T_7d25e_row0_col0, #T_7d25e_row0_col5, #T_7d25e_row0_col6, #T_7d25e_row1_col0, #T_7d25e_row1_col1, #T_7d25e_row1_col2, #T_7d25e_row1_col3, #T_7d25e_row1_col4, #T_7d25e_row1_col5, #T_7d25e_row1_col6, #T_7d25e_row2_col0, #T_7d25e_row2_col1, #T_7d25e_row2_col2, #T_7d25e_row2_col3, #T_7d25e_row2_col4, #T_7d25e_row2_col5, #T_7d25e_row2_col6, #T_7d25e_row3_col0, #T_7d25e_row3_col1, #T_7d25e_row3_col2, #T_7d25e_row3_col3, #T_7d25e_row3_col4, #T_7d25e_row3_col5, #T_7d25e_row3_col6, #T_7d25e_row4_col0, #T_7d25e_row4_col1, #T_7d25e_row4_col2, #T_7d25e_row4_col3, #T_7d25e_row4_col4, #T_7d25e_row4_col6, #T_7d25e_row5_col0, #T_7d25e_row5_col1, #T_7d25e_row5_col2, #T_7d25e_row5_col3, #T_7d25e_row5_col4, #T_7d25e_row5_col5, #T_7d25e_row5_col6, #T_7d25e_row6_col0, #T_7d25e_row6_col1, #T_7d25e_row6_col2, #T_7d25e_row6_col3, #T_7d25e_row6_col4, #T_7d25e_row6_col5, #T_7d25e_row6_col6, #T_7d25e_row7_col0, #T_7d25e_row7_col1, #T_7d25e_row7_col2, #T_7d25e_row7_col3, #T_7d25e_row7_col4, #T_7d25e_row7_col5, #T_7d25e_row8_col0, #T_7d25e_row8_col1, #T_7d25e_row8_col2, #T_7d25e_row8_col3, #T_7d25e_row8_col4, #T_7d25e_row8_col5, #T_7d25e_row8_col6, #T_7d25e_row9_col0, #T_7d25e_row9_col1, #T_7d25e_row9_col2, #T_7d25e_row9_col3, #T_7d25e_row9_col4, #T_7d25e_row9_col5, #T_7d25e_row9_col6, #T_7d25e_row10_col0, #T_7d25e_row10_col1, #T_7d25e_row10_col2, #T_7d25e_row10_col3, #T_7d25e_row10_col4, #T_7d25e_row10_col5, #T_7d25e_row10_col6, #T_7d25e_row11_col0, #T_7d25e_row11_col1, #T_7d25e_row11_col2, #T_7d25e_row11_col3, #T_7d25e_row11_col4, #T_7d25e_row11_col5, #T_7d25e_row11_col6, #T_7d25e_row12_col0, #T_7d25e_row12_col1, #T_7d25e_row12_col2, #T_7d25e_row12_col3, #T_7d25e_row12_col4, #T_7d25e_row12_col5, #T_7d25e_row12_col6, #T_7d25e_row13_col0, #T_7d25e_row13_col1, #T_7d25e_row13_col2, #T_7d25e_row13_col3, #T_7d25e_row13_col4, #T_7d25e_row13_col5, #T_7d25e_row13_col6, #T_7d25e_row14_col0, #T_7d25e_row14_col1, #T_7d25e_row14_col2, #T_7d25e_row14_col3, #T_7d25e_row14_col4, #T_7d25e_row14_col5, #T_7d25e_row14_col6, #T_7d25e_row15_col0, #T_7d25e_row15_col1, #T_7d25e_row15_col2, #T_7d25e_row15_col3, #T_7d25e_row15_col4, #T_7d25e_row15_col5, #T_7d25e_row15_col6, #T_7d25e_row16_col0, #T_7d25e_row16_col1, #T_7d25e_row16_col2, #T_7d25e_row16_col3, #T_7d25e_row16_col4, #T_7d25e_row16_col5, #T_7d25e_row16_col6, #T_7d25e_row17_col0, #T_7d25e_row17_col1, #T_7d25e_row17_col2, #T_7d25e_row17_col3, #T_7d25e_row17_col4, #T_7d25e_row17_col5, #T_7d25e_row17_col6, #T_7d25e_row18_col0, #T_7d25e_row18_col1, #T_7d25e_row18_col2, #T_7d25e_row18_col3, #T_7d25e_row18_col4, #T_7d25e_row18_col5, #T_7d25e_row18_col6 {
#   text-align: left;
# }
# #T_7d25e_row0_col1, #T_7d25e_row0_col2, #T_7d25e_row0_col3, #T_7d25e_row0_col4, #T_7d25e_row4_col5, #T_7d25e_row7_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7d25e_row0_col7, #T_7d25e_row1_col7, #T_7d25e_row2_col7, #T_7d25e_row3_col7, #T_7d25e_row4_col7, #T_7d25e_row5_col7, #T_7d25e_row6_col7, #T_7d25e_row7_col7, #T_7d25e_row8_col7, #T_7d25e_row10_col7, #T_7d25e_row11_col7, #T_7d25e_row12_col7, #T_7d25e_row13_col7, #T_7d25e_row14_col7, #T_7d25e_row16_col7, #T_7d25e_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7d25e_row9_col7, #T_7d25e_row15_col7, #T_7d25e_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7d25e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d25e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7d25e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7d25e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7d25e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7d25e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7d25e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7d25e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7d25e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d25e_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_7d25e_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_7d25e_row0_col1" class="data row0 col1" >46.4642</td>
#       <td id="T_7d25e_row0_col2" class="data row0 col2" >5089.7099</td>
#       <td id="T_7d25e_row0_col3" class="data row0 col3" >70.4694</td>
#       <td id="T_7d25e_row0_col4" class="data row0 col4" >0.8374</td>
#       <td id="T_7d25e_row0_col5" class="data row0 col5" >0.5920</td>
#       <td id="T_7d25e_row0_col6" class="data row0 col6" >0.7295</td>
#       <td id="T_7d25e_row0_col7" class="data row0 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_7d25e_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_7d25e_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7d25e_row1_col1" class="data row1 col1" >47.6458</td>
#       <td id="T_7d25e_row1_col2" class="data row1 col2" >5359.1867</td>
#       <td id="T_7d25e_row1_col3" class="data row1 col3" >72.1299</td>
#       <td id="T_7d25e_row1_col4" class="data row1 col4" >0.8304</td>
#       <td id="T_7d25e_row1_col5" class="data row1 col5" >0.5893</td>
#       <td id="T_7d25e_row1_col6" class="data row1 col6" >0.7676</td>
#       <td id="T_7d25e_row1_col7" class="data row1 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_7d25e_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_7d25e_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_7d25e_row2_col1" class="data row2 col1" >54.6984</td>
#       <td id="T_7d25e_row2_col2" class="data row2 col2" >6501.0571</td>
#       <td id="T_7d25e_row2_col3" class="data row2 col3" >79.5535</td>
#       <td id="T_7d25e_row2_col4" class="data row2 col4" >0.7924</td>
#       <td id="T_7d25e_row2_col5" class="data row2 col5" >0.6660</td>
#       <td id="T_7d25e_row2_col6" class="data row2 col6" >1.0206</td>
#       <td id="T_7d25e_row2_col7" class="data row2 col7" >0.0420</td>
#     </tr>
#     <tr>
#       <th id="T_7d25e_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_7d25e_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7d25e_row3_col1" class="data row3 col1" >57.1997</td>
#       <td id="T_7d25e_row3_col2" class="data row3 col2" >6933.2614</td>
#       <td id="T_7d25e_row3_col3" class="data row3 col3" >81.6927</td>
#       <td id="T_7d25e_row3_col4" class="data row3 col4" >0.7835</td>
#       <td id="T_7d25e_row3_col5" class="data row3 col5" >0.7765</td>
#       <td id="T_7d25e_row3_col6" class="data row3 col6" >1.2779</td>
#       <td id="T_7d25e_row3_col7" class="data row3 col7" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_7d25e_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_7d25e_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_7d25e_row4_col1" class="data row4 col1" >56.1901</td>
#       <td id="T_7d25e_row4_col2" class="data row4 col2" >7402.7947</td>
#       <td id="T_7d25e_row4_col3" class="data row4 col3" >84.5157</td>
#       <td id="T_7d25e_row4_col4" class="data row4 col4" >0.7665</td>
#       <td id="T_7d25e_row4_col5" class="data row4 col5" >0.5823</td>
#       <td id="T_7d25e_row4_col6" class="data row4 col6" >0.7489</td>
#       <td id="T_7d25e_row4_col7" class="data row4 col7" >0.0520</td>
#     </tr>
#     <tr>
#       <th id="T_7d25e_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_7d25e_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_7d25e_row5_col1" class="data row5 col1" >66.0314</td>
#       <td id="T_7d25e_row5_col2" class="data row5 col2" >9907.6314</td>
#       <td id="T_7d25e_row5_col3" class="data row5 col3" >98.4145</td>
#       <td id="T_7d25e_row5_col4" class="data row5 col4" >0.6805</td>
#       <td id="T_7d25e_row5_col5" class="data row

# %%
top3_exp1
# Out:
# [XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=-1,
#               num_parallel_tree=1, predictor='auto', random_state=555, ...),
#  LGBMRegressor(random_state=555),
#  ExtraTreesRegressor(n_jobs=-1, random_state=555)]

# %%
top3_exp2 = exp2.compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_d8cf2 th {
#   text-align: left;
# }
# #T_d8cf2_row0_col0, #T_d8cf2_row0_col5, #T_d8cf2_row0_col6, #T_d8cf2_row1_col0, #T_d8cf2_row1_col1, #T_d8cf2_row1_col2, #T_d8cf2_row1_col3, #T_d8cf2_row1_col4, #T_d8cf2_row1_col6, #T_d8cf2_row2_col0, #T_d8cf2_row2_col1, #T_d8cf2_row2_col2, #T_d8cf2_row2_col3, #T_d8cf2_row2_col4, #T_d8cf2_row2_col5, #T_d8cf2_row2_col6, #T_d8cf2_row3_col0, #T_d8cf2_row3_col1, #T_d8cf2_row3_col2, #T_d8cf2_row3_col3, #T_d8cf2_row3_col4, #T_d8cf2_row3_col5, #T_d8cf2_row3_col6, #T_d8cf2_row4_col0, #T_d8cf2_row4_col1, #T_d8cf2_row4_col2, #T_d8cf2_row4_col3, #T_d8cf2_row4_col4, #T_d8cf2_row4_col5, #T_d8cf2_row4_col6, #T_d8cf2_row5_col0, #T_d8cf2_row5_col1, #T_d8cf2_row5_col2, #T_d8cf2_row5_col3, #T_d8cf2_row5_col4, #T_d8cf2_row5_col5, #T_d8cf2_row5_col6, #T_d8cf2_row6_col0, #T_d8cf2_row6_col1, #T_d8cf2_row6_col2, #T_d8cf2_row6_col3, #T_d8cf2_row6_col4, #T_d8cf2_row6_col5, #T_d8cf2_row7_col0, #T_d8cf2_row7_col1, #T_d8cf2_row7_col2, #T_d8cf2_row7_col3, #T_d8cf2_row7_col4, #T_d8cf2_row7_col5, #T_d8cf2_row7_col6, #T_d8cf2_row8_col0, #T_d8cf2_row8_col1, #T_d8cf2_row8_col2, #T_d8cf2_row8_col3, #T_d8cf2_row8_col4, #T_d8cf2_row8_col5, #T_d8cf2_row8_col6, #T_d8cf2_row9_col0, #T_d8cf2_row9_col1, #T_d8cf2_row9_col2, #T_d8cf2_row9_col3, #T_d8cf2_row9_col4, #T_d8cf2_row9_col5, #T_d8cf2_row9_col6, #T_d8cf2_row10_col0, #T_d8cf2_row10_col1, #T_d8cf2_row10_col2, #T_d8cf2_row10_col3, #T_d8cf2_row10_col4, #T_d8cf2_row10_col5, #T_d8cf2_row10_col6, #T_d8cf2_row11_col0, #T_d8cf2_row11_col1, #T_d8cf2_row11_col2, #T_d8cf2_row11_col3, #T_d8cf2_row11_col4, #T_d8cf2_row11_col5, #T_d8cf2_row11_col6, #T_d8cf2_row12_col0, #T_d8cf2_row12_col1, #T_d8cf2_row12_col2, #T_d8cf2_row12_col3, #T_d8cf2_row12_col4, #T_d8cf2_row12_col5, #T_d8cf2_row12_col6, #T_d8cf2_row13_col0, #T_d8cf2_row13_col1, #T_d8cf2_row13_col2, #T_d8cf2_row13_col3, #T_d8cf2_row13_col4, #T_d8cf2_row13_col5, #T_d8cf2_row13_col6, #T_d8cf2_row14_col0, #T_d8cf2_row14_col1, #T_d8cf2_row14_col2, #T_d8cf2_row14_col3, #T_d8cf2_row14_col4, #T_d8cf2_row14_col5, #T_d8cf2_row14_col6, #T_d8cf2_row15_col0, #T_d8cf2_row15_col1, #T_d8cf2_row15_col2, #T_d8cf2_row15_col3, #T_d8cf2_row15_col4, #T_d8cf2_row15_col5, #T_d8cf2_row15_col6, #T_d8cf2_row16_col0, #T_d8cf2_row16_col1, #T_d8cf2_row16_col2, #T_d8cf2_row16_col3, #T_d8cf2_row16_col4, #T_d8cf2_row16_col5, #T_d8cf2_row16_col6, #T_d8cf2_row17_col0, #T_d8cf2_row17_col1, #T_d8cf2_row17_col2, #T_d8cf2_row17_col3, #T_d8cf2_row17_col4, #T_d8cf2_row17_col5, #T_d8cf2_row17_col6, #T_d8cf2_row18_col0, #T_d8cf2_row18_col1, #T_d8cf2_row18_col2, #T_d8cf2_row18_col3, #T_d8cf2_row18_col4, #T_d8cf2_row18_col5, #T_d8cf2_row18_col6 {
#   text-align: left;
# }
# #T_d8cf2_row0_col1, #T_d8cf2_row0_col2, #T_d8cf2_row0_col3, #T_d8cf2_row0_col4, #T_d8cf2_row1_col5, #T_d8cf2_row6_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d8cf2_row0_col7, #T_d8cf2_row1_col7, #T_d8cf2_row2_col7, #T_d8cf2_row3_col7, #T_d8cf2_row4_col7, #T_d8cf2_row5_col7, #T_d8cf2_row7_col7, #T_d8cf2_row8_col7, #T_d8cf2_row11_col7, #T_d8cf2_row13_col7, #T_d8cf2_row14_col7, #T_d8cf2_row15_col7, #T_d8cf2_row16_col7, #T_d8cf2_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d8cf2_row6_col7, #T_d8cf2_row9_col7, #T_d8cf2_row10_col7, #T_d8cf2_row12_col7, #T_d8cf2_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d8cf2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8cf2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d8cf2_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d8cf2_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d8cf2_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d8cf2_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d8cf2_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d8cf2_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d8cf2_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8cf2_level0_row0" class="row_heading level0 row0" >xgboost</th>
#       <td id="T_d8cf2_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_d8cf2_row0_col1" class="data row0 col1" >49.4748</td>
#       <td id="T_d8cf2_row0_col2" class="data row0 col2" >5624.0462</td>
#       <td id="T_d8cf2_row0_col3" class="data row0 col3" >74.3816</td>
#       <td id="T_d8cf2_row0_col4" class="data row0 col4" >0.8193</td>
#       <td id="T_d8cf2_row0_col5" class="data row0 col5" >0.6097</td>
#       <td id="T_d8cf2_row0_col6" class="data row0 col6" >0.8395</td>
#       <td id="T_d8cf2_row0_col7" class="data row0 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf2_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_d8cf2_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d8cf2_row1_col1" class="data row1 col1" >50.0216</td>
#       <td id="T_d8cf2_row1_col2" class="data row1 col2" >5999.7782</td>
#       <td id="T_d8cf2_row1_col3" class="data row1 col3" >76.3611</td>
#       <td id="T_d8cf2_row1_col4" class="data row1 col4" >0.8100</td>
#       <td id="T_d8cf2_row1_col5" class="data row1 col5" >0.6088</td>
#       <td id="T_d8cf2_row1_col6" class="data row1 col6" >0.8290</td>
#       <td id="T_d8cf2_row1_col7" class="data row1 col7" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf2_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_d8cf2_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_d8cf2_row2_col1" class="data row2 col1" >54.6212</td>
#       <td id="T_d8cf2_row2_col2" class="data row2 col2" >6587.9943</td>
#       <td id="T_d8cf2_row2_col3" class="data row2 col3" >80.1960</td>
#       <td id="T_d8cf2_row2_col4" class="data row2 col4" >0.7888</td>
#       <td id="T_d8cf2_row2_col5" class="data row2 col5" >0.6822</td>
#       <td id="T_d8cf2_row2_col6" class="data row2 col6" >1.0643</td>
#       <td id="T_d8cf2_row2_col7" class="data row2 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf2_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_d8cf2_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d8cf2_row3_col1" class="data row3 col1" >57.7972</td>
#       <td id="T_d8cf2_row3_col2" class="data row3 col2" >7087.3919</td>
#       <td id="T_d8cf2_row3_col3" class="data row3 col3" >82.7767</td>
#       <td id="T_d8cf2_row3_col4" class="data row3 col4" >0.7783</td>
#       <td id="T_d8cf2_row3_col5" class="data row3 col5" >0.7362</td>
#       <td id="T_d8cf2_row3_col6" class="data row3 col6" >1.1336</td>
#       <td id="T_d8cf2_row3_col7" class="data row3 col7" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf2_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_d8cf2_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_d8cf2_row4_col1" class="data row4 col1" >59.3032</td>
#       <td id="T_d8cf2_row4_col2" class="data row4 col2" >8243.2884</td>
#       <td id="T_d8cf2_row4_col3" class="data row4 col3" >89.2813</td>
#       <td id="T_d8cf2_row4_col4" class="data row4 col4" >0.7387</td>
#       <td id="T_d8cf2_row4_col5" class="data row4 col5" >0.6096</td>
#       <td id="T_d8cf2_row4_col6" class="data row4 col6" >0.8180</td>
#       <td id="T_d8cf2_row4_col7" class="data row4 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_d8cf2_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_d8cf2_row5_col0" class="data row5 col0" >AdaBoost Regressor</td>
#       <td id="T_d8cf2_row5_col1" class="data row5 col1" >94.7394</td>
#       <td id="T_d8cf2_row5_col2" class="data row5 col2" >12995.9890</td>
#       <td id="T_d8cf2_row5_col3" class="data row5 col3" >113.4944</td>
#       <td id="T_d8cf2_row5_col4" class="data row5 col4" >0.5770</td>
#       <td id="T_d8cf2_row5_col5" class="data row5

# %% [markdown]
# ## Create Model
#
# This function trains and evaluates the performance of a given estimator using cross validation. The output of this function is a score grid with CV scores by fold. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function. All the available models can be accessed using the models function.

# %%
xgboost = exp1.create_model('xgboost')
# Out:
# <style type="text/css">
# #T_67185_row10_col0, #T_67185_row10_col1, #T_67185_row10_col2, #T_67185_row10_col3, #T_67185_row10_col4, #T_67185_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_67185">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67185_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_67185_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_67185_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_67185_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_67185_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_67185_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67185_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67185_row0_col0" class="data row0 col0" >47.8984</td>
#       <td id="T_67185_row0_col1" class="data row0 col1" >4138.2892</td>
#       <td id="T_67185_row0_col2" class="data row0 col2" >64.3295</td>
#       <td id="T_67185_row0_col3" class="data row0 col3" >0.8534</td>
#       <td id="T_67185_row0_col4" class="data row0 col4" >0.4763</td>
#       <td id="T_67185_row0_col5" class="data row0 col5" >0.4259</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67185_row1_col0" class="data row1 col0" >34.0491</td>
#       <td id="T_67185_row1_col1" class="data row1 col1" >3522.0666</td>
#       <td id="T_67185_row1_col2" class="data row1 col2" >59.3470</td>
#       <td id="T_67185_row1_col3" class="data row1 col3" >0.8918</td>
#       <td id="T_67185_row1_col4" class="data row1 col4" >0.4751</td>
#       <td id="T_67185_row1_col5" class="data row1 col5" >0.4603</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_67185_row2_col0" class="data row2 col0" >55.5250</td>
#       <td id="T_67185_row2_col1" class="data row2 col1" >7487.2904</td>
#       <td id="T_67185_row2_col2" class="data row2 col2" >86.5291</td>
#       <td id="T_67185_row2_col3" class="data row2 col3" >0.7349</td>
#       <td id="T_67185_row2_col4" class="data row2 col4" >0.7313</td>
#       <td id="T_67185_row2_col5" class="data row2 col5" >1.1079</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_67185_row3_col0" class="data row3 col0" >38.5126</td>
#       <td id="T_67185_row3_col1" class="data row3 col1" >3093.4191</td>
#       <td id="T_67185_row3_col2" class="data row3 col2" >55.6185</td>
#       <td id="T_67185_row3_col3" class="data row3 col3" >0.8414</td>
#       <td id="T_67185_row3_col4" class="data row3 col4" >0.5822</td>
#       <td id="T_67185_row3_col5" class="data row3 col5" >0.5719</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_67185_row4_col0" class="data row4 col0" >47.0744</td>
#       <td id="T_67185_row4_col1" class="data row4 col1" >4849.8912</td>
#       <td id="T_67185_row4_col2" class="data row4 col2" >69.6412</td>
#       <td id="T_67185_row4_col3" class="data row4 col3" >0.8306</td>
#       <td id="T_67185_row4_col4" class="data row4 col4" >0.5470</td>
#       <td id="T_67185_row4_col5" class="data row4 col5" >0.6066</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_67185_row5_col0" class="data row5 col0" >53.0988</td>
#       <td id="T_67185_row5_col1" class="data row5 col1" >7086.4793</td>
#       <td id="T_67185_row5_col2" class="data row5 col2" >84.1812</td>
#       <td id="T_67185_row5_col3" class="data row5 col3" >0.8206</td>
#       <td id="T_67185_row5_col4" class="data row5 col4" >0.5150</td>
#       <td id="T_67185_row5_col5" class="data row5 col5" >0.6090</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_67185_row6_col0" class="data row6 col0" >41.9417</td>
#       <td id="T_67185_row6_col1" class="data row6 col1" >3709.5857</td>
#       <td id="T_67185_row6_col2" class="data row6 col2" >60.9064</td>
#       <td id="T_67185_row6_col3" class="data row6 col3" >0.8794</td>
#       <td id="T_67185_row6_col4" class="data row6 col4" >0.6831</td>
#       <td id="T_67185_row6_col5" class="data row6 col5" >0.5776</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_67185_row7_col0" class="data row7 col0" >53.8873</td>
#       <td id="T_67185_row7_col1" class="data row7 col1" >6747.2444</td>
#       <td id="T_67185_row7_col2" class="data row7 col2" >82.1416</td>
#       <td id="T_67185_row7_col3" class="data row7 col3" >0.8348</td>
#       <td id="T_67185_row7_col4" class="data row7 col4" >0.6582</td>
#       <td id="T_67185_row7_col5" class="data row7 col5" >0.7776</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_67185_row8_col0" class="data row8 col0" >55.1904</td>
#       <td id="T_67185_row8_col1" class="data row8 col1" >6481.6988</td>
#       <td id="T_67185_row8_col2" class="data row8 col2" >80.5090</td>
#       <td id="T_67185_row8_col3" class="data row8 col3" >0.8432</td>
#       <td id="T_67185_row8_col4" class="data row8 col4" >0.6406</td>
#       <td id="T_67185_row8_col5" class="data row8 col5" >1.2897</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_67185_row9_col0" class="data row9 col0" >37.4642</td>
#       <td id="T_67185_row9_col1" class="data row9 col1" >3781.1347</td>
#       <td id="T_67185_row9_col2" class="data row9 col2" >61.4909</td>
#       <td id="T_67185_row9_col3" class="data row9 col3" >0.8441</td>
#       <td id="T_67185_row9_col4" class="data row9 col4" >0.6111</td>
#       <td id="T_67185_row9_col5" class="data row9 col5" >0.8689</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_67185_row10_col0" class="data row10 col0" >46.4642</td>
#       <td id="T_67185_row10_col1" class="data row10 col1" >5089.7099</td>
#       <td id="T_67185_row10_col2" class="data row10 col2" >70.4694</td>
#       <td id="T_67185_row10_col3" class="data row10 col3" >0.8374</td>
#       <td id="T_67185_row10_col4" class="data row10 col4" >0.5920</td>
#       <td id="T_67185_row10_col5" class="data row10 col5" >0.7295</td>
#     </tr>
#     <tr>
#       <th id="T_67185_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_67185_row11_col0" class="data row11 col0" >7.6066</td>
#       <td id="T_67185_row11_col1" class="data row11 col1" >1595.0875</td>
#       <td id="T_67185_row11_col2" class="data row11 col2" >11.1251</td>
#       <td id="T_67185_row11_col3" class="data row11 col3" >0.0399</td>
#       <td id="T_67185_row11_col4" class="data row11 col4" >0.0836</td>
#       <td id="T_67185_row11_col5" class="data row11 col5" >0.2685</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Tune model
#
# This function tunes the hyperparameters of a given estimator. The output of this function is a score grid with CV scores by fold of the best selected model based on optimize parameter. Metrics evaluated during CV can be accessed using the get_metrics function. Custom metrics can be added or removed using add_metric and remove_metric function.

# %%
tune_xgboost = exp1.tune_model(xgboost)
# Out:
# <style type="text/css">
# #T_27555_row10_col0, #T_27555_row10_col1, #T_27555_row10_col2, #T_27555_row10_col3, #T_27555_row10_col4, #T_27555_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_27555">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27555_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_27555_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_27555_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_27555_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_27555_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_27555_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27555_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27555_row0_col0" class="data row0 col0" >52.0442</td>
#       <td id="T_27555_row0_col1" class="data row0 col1" >4731.2659</td>
#       <td id="T_27555_row0_col2" class="data row0 col2" >68.7842</td>
#       <td id="T_27555_row0_col3" class="data row0 col3" >0.8324</td>
#       <td id="T_27555_row0_col4" class="data row0 col4" >0.4804</td>
#       <td id="T_27555_row0_col5" class="data row0 col5" >0.4693</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27555_row1_col0" class="data row1 col0" >34.2464</td>
#       <td id="T_27555_row1_col1" class="data row1 col1" >2910.3166</td>
#       <td id="T_27555_row1_col2" class="data row1 col2" >53.9474</td>
#       <td id="T_27555_row1_col3" class="data row1 col3" >0.9106</td>
#       <td id="T_27555_row1_col4" class="data row1 col4" >0.6517</td>
#       <td id="T_27555_row1_col5" class="data row1 col5" >0.6745</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27555_row2_col0" class="data row2 col0" >42.3598</td>
#       <td id="T_27555_row2_col1" class="data row2 col1" >4168.7450</td>
#       <td id="T_27555_row2_col2" class="data row2 col2" >64.5658</td>
#       <td id="T_27555_row2_col3" class="data row2 col3" >0.8524</td>
#       <td id="T_27555_row2_col4" class="data row2 col4" >0.7173</td>
#       <td id="T_27555_row2_col5" class="data row2 col5" >1.1182</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27555_row3_col0" class="data row3 col0" >38.6412</td>
#       <td id="T_27555_row3_col1" class="data row3 col1" >3500.7020</td>
#       <td id="T_27555_row3_col2" class="data row3 col2" >59.1667</td>
#       <td id="T_27555_row3_col3" class="data row3 col3" >0.8205</td>
#       <td id="T_27555_row3_col4" class="data row3 col4" >0.6742</td>
#       <td id="T_27555_row3_col5" class="data row3 col5" >0.8055</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27555_row4_col0" class="data row4 col0" >47.3610</td>
#       <td id="T_27555_row4_col1" class="data row4 col1" >4535.8741</td>
#       <td id="T_27555_row4_col2" class="data row4 col2" >67.3489</td>
#       <td id="T_27555_row4_col3" class="data row4 col3" >0.8416</td>
#       <td id="T_27555_row4_col4" class="data row4 col4" >0.7220</td>
#       <td id="T_27555_row4_col5" class="data row4 col5" >0.9740</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27555_row5_col0" class="data row5 col0" >59.3761</td>
#       <td id="T_27555_row5_col1" class="data row5 col1" >7593.7696</td>
#       <td id="T_27555_row5_col2" class="data row5 col2" >87.1422</td>
#       <td id="T_27555_row5_col3" class="data row5 col3" >0.8077</td>
#       <td id="T_27555_row5_col4" class="data row5 col4" >0.7019</td>
#       <td id="T_27555_row5_col5" class="data row5 col5" >1.2028</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27555_row6_col0" class="data row6 col0" >40.0462</td>
#       <td id="T_27555_row6_col1" class="data row6 col1" >2993.4000</td>
#       <td id="T_27555_row6_col2" class="data row6 col2" >54.7120</td>
#       <td id="T_27555_row6_col3" class="data row6 col3" >0.9027</td>
#       <td id="T_27555_row6_col4" class="data row6 col4" >0.7241</td>
#       <td id="T_27555_row6_col5" class="data row6 col5" >1.1231</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27555_row7_col0" class="data row7 col0" >60.5507</td>
#       <td id="T_27555_row7_col1" class="data row7 col1" >6775.9880</td>
#       <td id="T_27555_row7_col2" class="data row7 col2" >82.3164</td>
#       <td id="T_27555_row7_col3" class="data row7 col3" >0.8340</td>
#       <td id="T_27555_row7_col4" class="data row7 col4" >0.8004</td>
#       <td id="T_27555_row7_col5" class="data row7 col5" >1.4325</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27555_row8_col0" class="data row8 col0" >55.9826</td>
#       <td id="T_27555_row8_col1" class="data row8 col1" >6789.7116</td>
#       <td id="T_27555_row8_col2" class="data row8 col2" >82.3997</td>
#       <td id="T_27555_row8_col3" class="data row8 col3" >0.8358</td>
#       <td id="T_27555_row8_col4" class="data row8 col4" >0.6597</td>
#       <td id="T_27555_row8_col5" class="data row8 col5" >0.9216</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27555_row9_col0" class="data row9 col0" >40.8836</td>
#       <td id="T_27555_row9_col1" class="data row9 col1" >4826.7390</td>
#       <td id="T_27555_row9_col2" class="data row9 col2" >69.4747</td>
#       <td id="T_27555_row9_col3" class="data row9 col3" >0.8010</td>
#       <td id="T_27555_row9_col4" class="data row9 col4" >0.6944</td>
#       <td id="T_27555_row9_col5" class="data row9 col5" >1.0271</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_27555_row10_col0" class="data row10 col0" >47.1492</td>
#       <td id="T_27555_row10_col1" class="data row10 col1" >4882.6512</td>
#       <td id="T_27555_row10_col2" class="data row10 col2" >68.9858</td>
#       <td id="T_27555_row10_col3" class="data row10 col3" >0.8439</td>
#       <td id="T_27555_row10_col4" class="data row10 col4" >0.6826</td>
#       <td id="T_27555_row10_col5" class="data row10 col5" >0.9749</td>
#     </tr>
#     <tr>
#       <th id="T_27555_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_27555_row11_col0" class="data row11 col0" >8.8467</td>
#       <td id="T_27555_row11_col1" class="data row11 col1" >1568.3394</td>
#       <td id="T_27555_row11_col2" class="data row11 col2" >11.1180</td>
#       <td id="T_27555_row11_col3" class="data row11 col3" >0.0346</td>
#       <td id="T_27555_row11_col4" class="data row11 col4" >0.0783</td>
#       <td id="T_27555_row11_col5" class="data row11 col5" >0.2615</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
xgboost
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=555, ...)

# %%
tune_xgboost
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.1, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=2, missing=nan,
#              monotone_constraints='()', n_estimators=240, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=555, ...)

# %% [markdown]
# ## Plot Model
#
# This function analyzes the performance of a trained model on holdout set. It may require re-training the model in certain cases

# %%
exp1.plot_model(tune_xgboost)

# %%
exp1.plot_model(tune_xgboost, plot = 'error')

# %%
exp1.plot_model(tune_xgboost, plot = 'feature')

# %%
exp1.plot_model(tune_xgboost, plot = 'parameter')
# Out:
#                                Parameters
# objective                reg:squarederror
# base_score                            0.5
# booster                            gbtree
# callbacks                            None
# colsample_bylevel                       1
# colsample_bynode                        1
# colsample_bytree                      0.7
# early_stopping_rounds                None
# enable_categorical                  False
# eval_metric                          None
# feature_types                        None
# gamma                                   0
# gpu_id                                 -1
# grow_policy                     depthwise
# importance_type                      None
# interaction_constraints
# learning_rate                         0.1
# max_bin                               256
# max_cat_threshold                      64
# max_cat_to_onehot                       4
# max_delta_step                          0
# max_depth                               6
# max_leaves                              0
# min_child_weight                        2
# missing                               nan
# monotone_constraints                   ()
# n_estimators                          240
# n_jobs                                 -1
# num_parallel_tree                       1
# predictor                            auto
# random_state                          555
# reg_alpha                           0.001
# reg_lambda                              4
# sampling_method                   uniform
# scale_pos_weight                     16.7
# subsample                             0.7
# tree_method                          auto
# validate_parameters                     1
# verbosity                               0

# %%
exp1.plot_model(tune_xgboost, plot = 'learning')

# %% [markdown]
# the model has high variance, increasing sample size will help.

# %%
exp1.plot_model(tune_xgboost, plot = 'vc')

# %% [markdown]
# As you can see, the model is overfitting with max_depth = 9.

# %%
exp1.plot_model(tune_xgboost, plot = 'manifold')

# %% [markdown]
# ## Evaluate model
#
# This function displays a user interface for analyzing performance of a trained model. It calls the plot_model function internally.
#
# *I don't recommend using this evaluate model functionality! very slow plus bugs! do separate plots instead.*

# %%
lr = exp1.create_model('lr', fold=5)
# Out:
# <style type="text/css">
# #T_8339e_row5_col0, #T_8339e_row5_col1, #T_8339e_row5_col2, #T_8339e_row5_col3, #T_8339e_row5_col4, #T_8339e_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8339e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8339e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8339e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8339e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8339e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8339e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8339e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8339e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8339e_row0_col0" class="data row0 col0" >101.3101</td>
#       <td id="T_8339e_row0_col1" class="data row0 col1" >18282.7274</td>
#       <td id="T_8339e_row0_col2" class="data row0 col2" >135.2136</td>
#       <td id="T_8339e_row0_col3" class="data row0 col3" >0.4012</td>
#       <td id="T_8339e_row0_col4" class="data row0 col4" >1.1199</td>
#       <td id="T_8339e_row0_col5" class="data row0 col5" >2.4310</td>
#     </tr>
#     <tr>
#       <th id="T_8339e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8339e_row1_col0" class="data row1 col0" >95.7498</td>
#       <td id="T_8339e_row1_col1" class="data row1 col1" >15110.2642</td>
#       <td id="T_8339e_row1_col2" class="data row1 col2" >122.9238</td>
#       <td id="T_8339e_row1_col3" class="data row1 col3" >0.3773</td>
#       <td id="T_8339e_row1_col4" class="data row1 col4" >1.2613</td>
#       <td id="T_8339e_row1_col5" class="data row1 col5" >4.7661</td>
#     </tr>
#     <tr>
#       <th id="T_8339e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8339e_row2_col0" class="data row2 col0" >114.7332</td>
#       <td id="T_8339e_row2_col1" class="data row2 col1" >24543.6374</td>
#       <td id="T_8339e_row2_col2" class="data row2 col2" >156.6641</td>
#       <td id="T_8339e_row2_col3" class="data row2 col3" >0.2891</td>
#       <td id="T_8339e_row2_col4" class="data row2 col4" >1.3198</td>
#       <td id="T_8339e_row2_col5" class="data row2 col5" >4.5130</td>
#     </tr>
#     <tr>
#       <th id="T_8339e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8339e_row3_col0" class="data row3 col0" >108.3152</td>
#       <td id="T_8339e_row3_col1" class="data row3 col1" >21763.7850</td>
#       <td id="T_8339e_row3_col2" class="data row3 col2" >147.5255</td>
#       <td id="T_8339e_row3_col3" class="data row3 col3" >0.3949</td>
#       <td id="T_8339e_row3_col4" class="data row3 col4" >1.3007</td>
#       <td id="T_8339e_row3_col5" class="data row3 col5" >3.6824</td>
#     </tr>
#     <tr>
#       <th id="T_8339e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8339e_row4_col0" class="data row4 col0" >102.7550</td>
#       <td id="T_8339e_row4_col1" class="data row4 col1" >19300.9429</td>
#       <td id="T_8339e_row4_col2" class="data row4 col2" >138.9278</td>
#       <td id="T_8339e_row4_col3" class="data row4 col3" >0.4405</td>
#       <td id="T_8339e_row4_col4" class="data row4 col4" >1.2417</td>
#       <td id="T_8339e_row4_col5" class="data row4 col5" >4.1147</td>
#     </tr>
#     <tr>
#       <th id="T_8339e_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_8339e_row5_col0" class="data row5 col0" >104.5727</td>
#       <td id="T_8339e_row5_col1" class="data row5 col1" >19800.2714</td>
#       <td id="T_8339e_row5_col2" class="data row5 col2" >140.2510</td>
#       <td id="T_8339e_row5_col3" class="data row5 col3" >0.3806</td>
#       <td id="T_8339e_row5_col4" class="data row5 col4" >1.2487</td>
#       <td id="T_8339e_row5_col5" class="data row5 col5" >3.9015</td>
#     </tr>
#     <tr>
#       <th id="T_8339e_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_8339e_row6_col0" class="data row6 col0" >6.4658</td>
#       <td id="T_8339e_row6_col1" class="data row6 col1" >3190.7160</td>
#       <td id="T_8339e_row6_col2" class="data row6 col2" >11.3988</td>
#       <td id="T_8339e_row6_col3" class="data row6 col3" >0.0502</td>
#       <td id="T_8339e_row6_col4" class="data row6 col4" >0.0701</td>
#       <td id="T_8339e_row6_col5" class="data row6 col5" >0.8219</td>
#     </tr>
#   </tbody>
# </table>

# %%
exp1.evaluate_model(lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# ## Interpret model
#
# This function analyzes the predictions generated from a trained model. Most plots in this function are implemented based on the SHAP (SHapley Additive exPlanations). For more info on this, please see https://shap.readthedocs.io/en/latest/

# %%
exp1.interpret_model(tune_xgboost)

# %% [markdown]
# ## Ensemble a Model
# Ensembling is a common machine learning technique used to improve the performance of models (mostly tree based). There are various techniques for ensembling that we will cover in this section. These include Bagging and Boosting

# %%
# lets create a simple decision tree model that we will use for ensembling 
dt = exp1.create_model('dt')
# Out:
# <style type="text/css">
# #T_f42f9_row10_col0, #T_f42f9_row10_col1, #T_f42f9_row10_col2, #T_f42f9_row10_col3, #T_f42f9_row10_col4, #T_f42f9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f42f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f42f9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f42f9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f42f9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f42f9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f42f9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f42f9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f42f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f42f9_row0_col0" class="data row0 col0" >68.0635</td>
#       <td id="T_f42f9_row0_col1" class="data row0 col1" >10545.0476</td>
#       <td id="T_f42f9_row0_col2" class="data row0 col2" >102.6891</td>
#       <td id="T_f42f9_row0_col3" class="data row0 col3" >0.6266</td>
#       <td id="T_f42f9_row0_col4" class="data row0 col4" >0.6847</td>
#       <td id="T_f42f9_row0_col5" class="data row0 col5" >0.5030</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f42f9_row1_col0" class="data row1 col0" >67.5397</td>
#       <td id="T_f42f9_row1_col1" class="data row1 col1" >16466.2698</td>
#       <td id="T_f42f9_row1_col2" class="data row1 col2" >128.3210</td>
#       <td id="T_f42f9_row1_col3" class="data row1 col3" >0.4940</td>
#       <td id="T_f42f9_row1_col4" class="data row1 col4" >0.6592</td>
#       <td id="T_f42f9_row1_col5" class="data row1 col5" >0.6359</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f42f9_row2_col0" class="data row2 col0" >76.2222</td>
#       <td id="T_f42f9_row2_col1" class="data row2 col1" >15860.2540</td>
#       <td id="T_f42f9_row2_col2" class="data row2 col2" >125.9375</td>
#       <td id="T_f42f9_row2_col3" class="data row2 col3" >0.4383</td>
#       <td id="T_f42f9_row2_col4" class="data row2 col4" >0.5413</td>
#       <td id="T_f42f9_row2_col5" class="data row2 col5" >0.4577</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f42f9_row3_col0" class="data row3 col0" >61.3016</td>
#       <td id="T_f42f9_row3_col1" class="data row3 col1" >11490.5079</td>
#       <td id="T_f42f9_row3_col2" class="data row3 col2" >107.1938</td>
#       <td id="T_f42f9_row3_col3" class="data row3 col3" >0.4110</td>
#       <td id="T_f42f9_row3_col4" class="data row3 col4" >0.6600</td>
#       <td id="T_f42f9_row3_col5" class="data row3 col5" >0.6664</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f42f9_row4_col0" class="data row4 col0" >71.8254</td>
#       <td id="T_f42f9_row4_col1" class="data row4 col1" >11495.7619</td>
#       <td id="T_f42f9_row4_col2" class="data row4 col2" >107.2183</td>
#       <td id="T_f42f9_row4_col3" class="data row4 col3" >0.5986</td>
#       <td id="T_f42f9_row4_col4" class="data row4 col4" >0.6624</td>
#       <td id="T_f42f9_row4_col5" class="data row4 col5" >0.6492</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f42f9_row5_col0" class="data row5 col0" >86.1746</td>
#       <td id="T_f42f9_row5_col1" class="data row5 col1" >18909.4127</td>
#       <td id="T_f42f9_row5_col2" class="data row5 col2" >137.5115</td>
#       <td id="T_f42f9_row5_col3" class="data row5 col3" >0.5212</td>
#       <td id="T_f42f9_row5_col4" class="data row5 col4" >0.6782</td>
#       <td id="T_f42f9_row5_col5" class="data row5 col5" >0.8048</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f42f9_row6_col0" class="data row6 col0" >75.4127</td>
#       <td id="T_f42f9_row6_col1" class="data row6 col1" >13231.8571</td>
#       <td id="T_f42f9_row6_col2" class="data row6 col2" >115.0298</td>
#       <td id="T_f42f9_row6_col3" class="data row6 col3" >0.5699</td>
#       <td id="T_f42f9_row6_col4" class="data row6 col4" >0.8320</td>
#       <td id="T_f42f9_row6_col5" class="data row6 col5" >1.1336</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f42f9_row7_col0" class="data row7 col0" >100.4921</td>
#       <td id="T_f42f9_row7_col1" class="data row7 col1" >30237.0317</td>
#       <td id="T_f42f9_row7_col2" class="data row7 col2" >173.8880</td>
#       <td id="T_f42f9_row7_col3" class="data row7 col3" >0.2595</td>
#       <td id="T_f42f9_row7_col4" class="data row7 col4" >0.6564</td>
#       <td id="T_f42f9_row7_col5" class="data row7 col5" >0.5561</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f42f9_row8_col0" class="data row8 col0" >71.4921</td>
#       <td id="T_f42f9_row8_col1" class="data row8 col1" >9087.4286</td>
#       <td id="T_f42f9_row8_col2" class="data row8 col2" >95.3280</td>
#       <td id="T_f42f9_row8_col3" class="data row8 col3" >0.7802</td>
#       <td id="T_f42f9_row8_col4" class="data row8 col4" >0.6340</td>
#       <td id="T_f42f9_row8_col5" class="data row8 col5" >0.6963</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f42f9_row9_col0" class="data row9 col0" >86.1935</td>
#       <td id="T_f42f9_row9_col1" class="data row9 col1" >21123.6452</td>
#       <td id="T_f42f9_row9_col2" class="data row9 col2" >145.3398</td>
#       <td id="T_f42f9_row9_col3" class="data row9 col3" >0.1291</td>
#       <td id="T_f42f9_row9_col4" class="data row9 col4" >0.7941</td>
#       <td id="T_f42f9_row9_col5" class="data row9 col5" >1.1163</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f42f9_row10_col0" class="data row10 col0" >76.4717</td>
#       <td id="T_f42f9_row10_col1" class="data row10 col1" >15844.7217</td>
#       <td id="T_f42f9_row10_col2" class="data row10 col2" >123.8457</td>
#       <td id="T_f42f9_row10_col3" class="data row10 col3" >0.4828</td>
#       <td id="T_f42f9_row10_col4" class="data row10 col4" >0.6802</td>
#       <td id="T_f42f9_row10_col5" class="data row10 col5" >0.7219</td>
#     </tr>
#     <tr>
#       <th id="T_f42f9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f42f9_row11_col0" class="data row11 col0" >10.9262</td>
#       <td id="T_f42f9_row11_col1" class="data row11 col1" >6026.8712</td>
#       <td id="T_f42f9_row11_col2" class="data row11 col2" >22.5160</td>
#       <td id="T_f42f9_row11_col3" class="data row11 col3" >0.1772</td>
#       <td id="T_f42f9_row11_col4" class="data row11 col4" >0.0769</td>
#       <td id="T_f42f9_row11_col5" class="data row11 col5" >0.2222</td>
#     </tr>
#   </tbody>
# </table>

# %%
bagged_dt = exp1.ensemble_model(dt)
# Out:
# <style type="text/css">
# #T_e3492_row10_col0, #T_e3492_row10_col1, #T_e3492_row10_col2, #T_e3492_row10_col3, #T_e3492_row10_col4, #T_e3492_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e3492">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3492_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e3492_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e3492_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e3492_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e3492_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e3492_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3492_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3492_row0_col0" class="data row0 col0" >68.2286</td>
#       <td id="T_e3492_row0_col1" class="data row0 col1" >8815.8965</td>
#       <td id="T_e3492_row0_col2" class="data row0 col2" >93.8930</td>
#       <td id="T_e3492_row0_col3" class="data row0 col3" >0.6878</td>
#       <td id="T_e3492_row0_col4" class="data row0 col4" >0.5652</td>
#       <td id="T_e3492_row0_col5" class="data row0 col5" >0.6071</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3492_row1_col0" class="data row1 col0" >39.3460</td>
#       <td id="T_e3492_row1_col1" class="data row1 col1" >4236.4467</td>
#       <td id="T_e3492_row1_col2" class="data row1 col2" >65.0880</td>
#       <td id="T_e3492_row1_col3" class="data row1 col3" >0.8698</td>
#       <td id="T_e3492_row1_col4" class="data row1 col4" >0.4450</td>
#       <td id="T_e3492_row1_col5" class="data row1 col5" >0.4917</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3492_row2_col0" class="data row2 col0" >54.8603</td>
#       <td id="T_e3492_row2_col1" class="data row2 col1" >7471.5952</td>
#       <td id="T_e3492_row2_col2" class="data row2 col2" >86.4384</td>
#       <td id="T_e3492_row2_col3" class="data row2 col3" >0.7354</td>
#       <td id="T_e3492_row2_col4" class="data row2 col4" >0.5702</td>
#       <td id="T_e3492_row2_col5" class="data row2 col5" >0.7096</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3492_row3_col0" class="data row3 col0" >48.4508</td>
#       <td id="T_e3492_row3_col1" class="data row3 col1" >5044.0657</td>
#       <td id="T_e3492_row3_col2" class="data row3 col2" >71.0216</td>
#       <td id="T_e3492_row3_col3" class="data row3 col3" >0.7414</td>
#       <td id="T_e3492_row3_col4" class="data row3 col4" >0.5529</td>
#       <td id="T_e3492_row3_col5" class="data row3 col5" >0.6374</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3492_row4_col0" class="data row4 col0" >63.6556</td>
#       <td id="T_e3492_row4_col1" class="data row4 col1" >8409.8729</td>
#       <td id="T_e3492_row4_col2" class="data row4 col2" >91.7054</td>
#       <td id="T_e3492_row4_col3" class="data row4 col3" >0.7063</td>
#       <td id="T_e3492_row4_col4" class="data row4 col4" >0.5952</td>
#       <td id="T_e3492_row4_col5" class="data row4 col5" >0.7299</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3492_row5_col0" class="data row5 col0" >78.9683</td>
#       <td id="T_e3492_row5_col1" class="data row5 col1" >15625.9397</td>
#       <td id="T_e3492_row5_col2" class="data row5 col2" >125.0038</td>
#       <td id="T_e3492_row5_col3" class="data row5 col3" >0.6044</td>
#       <td id="T_e3492_row5_col4" class="data row5 col4" >0.6383</td>
#       <td id="T_e3492_row5_col5" class="data row5 col5" >0.8153</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3492_row6_col0" class="data row6 col0" >59.5413</td>
#       <td id="T_e3492_row6_col1" class="data row6 col1" >8438.1656</td>
#       <td id="T_e3492_row6_col2" class="data row6 col2" >91.8595</td>
#       <td id="T_e3492_row6_col3" class="data row6 col3" >0.7257</td>
#       <td id="T_e3492_row6_col4" class="data row6 col4" >0.6914</td>
#       <td id="T_e3492_row6_col5" class="data row6 col5" >0.9684</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3492_row7_col0" class="data row7 col0" >68.9714</td>
#       <td id="T_e3492_row7_col1" class="data row7 col1" >11940.6673</td>
#       <td id="T_e3492_row7_col2" class="data row7 col2" >109.2734</td>
#       <td id="T_e3492_row7_col3" class="data row7 col3" >0.7076</td>
#       <td id="T_e3492_row7_col4" class="data row7 col4" >0.5594</td>
#       <td id="T_e3492_row7_col5" class="data row7 col5" >0.6462</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3492_row8_col0" class="data row8 col0" >69.5016</td>
#       <td id="T_e3492_row8_col1" class="data row8 col1" >10059.2641</td>
#       <td id="T_e3492_row8_col2" class="data row8 col2" >100.2959</td>
#       <td id="T_e3492_row8_col3" class="data row8 col3" >0.7567</td>
#       <td id="T_e3492_row8_col4" class="data row8 col4" >0.5751</td>
#       <td id="T_e3492_row8_col5" class="data row8 col5" >0.7055</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3492_row9_col0" class="data row9 col0" >48.4371</td>
#       <td id="T_e3492_row9_col1" class="data row9 col1" >6144.1415</td>
#       <td id="T_e3492_row9_col2" class="data row9 col2" >78.3846</td>
#       <td id="T_e3492_row9_col3" class="data row9 col3" >0.7467</td>
#       <td id="T_e3492_row9_col4" class="data row9 col4" >0.6745</td>
#       <td id="T_e3492_row9_col5" class="data row9 col5" >0.9807</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e3492_row10_col0" class="data row10 col0" >59.9961</td>
#       <td id="T_e3492_row10_col1" class="data row10 col1" >8618.6055</td>
#       <td id="T_e3492_row10_col2" class="data row10 col2" >91.2963</td>
#       <td id="T_e3492_row10_col3" class="data row10 col3" >0.7282</td>
#       <td id="T_e3492_row10_col4" class="data row10 col4" >0.5867</td>
#       <td id="T_e3492_row10_col5" class="data row10 col5" >0.7292</td>
#     </tr>
#     <tr>
#       <th id="T_e3492_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e3492_row11_col0" class="data row11 col0" >11.5409</td>
#       <td id="T_e3492_row11_col1" class="data row11 col1" >3189.8061</td>
#       <td id="T_e3492_row11_col2" class="data row11 col2" >16.8399</td>
#       <td id="T_e3492_row11_col3" class="data row11 col3" >0.0627</td>
#       <td id="T_e3492_row11_col4" class="data row11 col4" >0.0665</td>
#       <td id="T_e3492_row11_col5" class="data row11 col5" >0.1468</td>
#     </tr>
#   </tbody>
# </table>

# %%
boosted_dt = exp1.ensemble_model(dt, method = 'Boosting')
# Out:
# <style type="text/css">
# #T_e174a_row10_col0, #T_e174a_row10_col1, #T_e174a_row10_col2, #T_e174a_row10_col3, #T_e174a_row10_col4, #T_e174a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e174a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e174a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e174a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e174a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e174a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e174a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e174a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e174a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e174a_row0_col0" class="data row0 col0" >69.7778</td>
#       <td id="T_e174a_row0_col1" class="data row0 col1" >9344.6032</td>
#       <td id="T_e174a_row0_col2" class="data row0 col2" >96.6675</td>
#       <td id="T_e174a_row0_col3" class="data row0 col3" >0.6691</td>
#       <td id="T_e174a_row0_col4" class="data row0 col4" >0.5923</td>
#       <td id="T_e174a_row0_col5" class="data row0 col5" >0.5179</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e174a_row1_col0" class="data row1 col0" >42.3175</td>
#       <td id="T_e174a_row1_col1" class="data row1 col1" >4530.7619</td>
#       <td id="T_e174a_row1_col2" class="data row1 col2" >67.3109</td>
#       <td id="T_e174a_row1_col3" class="data row1 col3" >0.8608</td>
#       <td id="T_e174a_row1_col4" class="data row1 col4" >0.4616</td>
#       <td id="T_e174a_row1_col5" class="data row1 col5" >0.4571</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e174a_row2_col0" class="data row2 col0" >64.5238</td>
#       <td id="T_e174a_row2_col1" class="data row2 col1" >9958.3016</td>
#       <td id="T_e174a_row2_col2" class="data row2 col2" >99.7913</td>
#       <td id="T_e174a_row2_col3" class="data row2 col3" >0.6473</td>
#       <td id="T_e174a_row2_col4" class="data row2 col4" >0.6643</td>
#       <td id="T_e174a_row2_col5" class="data row2 col5" >0.9851</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e174a_row3_col0" class="data row3 col0" >51.9365</td>
#       <td id="T_e174a_row3_col1" class="data row3 col1" >6490.6349</td>
#       <td id="T_e174a_row3_col2" class="data row3 col2" >80.5645</td>
#       <td id="T_e174a_row3_col3" class="data row3 col3" >0.6673</td>
#       <td id="T_e174a_row3_col4" class="data row3 col4" >0.5368</td>
#       <td id="T_e174a_row3_col5" class="data row3 col5" >0.6044</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e174a_row4_col0" class="data row4 col0" >55.3016</td>
#       <td id="T_e174a_row4_col1" class="data row4 col1" >6379.4603</td>
#       <td id="T_e174a_row4_col2" class="data row4 col2" >79.8715</td>
#       <td id="T_e174a_row4_col3" class="data row4 col3" >0.7772</td>
#       <td id="T_e174a_row4_col4" class="data row4 col4" >0.5855</td>
#       <td id="T_e174a_row4_col5" class="data row4 col5" >0.7167</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e174a_row5_col0" class="data row5 col0" >72.6667</td>
#       <td id="T_e174a_row5_col1" class="data row5 col1" >14692.0952</td>
#       <td id="T_e174a_row5_col2" class="data row5 col2" >121.2110</td>
#       <td id="T_e174a_row5_col3" class="data row5 col3" >0.6280</td>
#       <td id="T_e174a_row5_col4" class="data row5 col4" >0.5887</td>
#       <td id="T_e174a_row5_col5" class="data row5 col5" >0.6786</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e174a_row6_col0" class="data row6 col0" >53.6667</td>
#       <td id="T_e174a_row6_col1" class="data row6 col1" >7233.1905</td>
#       <td id="T_e174a_row6_col2" class="data row6 col2" >85.0482</td>
#       <td id="T_e174a_row6_col3" class="data row6 col3" >0.7649</td>
#       <td id="T_e174a_row6_col4" class="data row6 col4" >0.7267</td>
#       <td id="T_e174a_row6_col5" class="data row6 col5" >1.0393</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e174a_row7_col0" class="data row7 col0" >72.3651</td>
#       <td id="T_e174a_row7_col1" class="data row7 col1" >11617.7302</td>
#       <td id="T_e174a_row7_col2" class="data row7 col2" >107.7856</td>
#       <td id="T_e174a_row7_col3" class="data row7 col3" >0.7155</td>
#       <td id="T_e174a_row7_col4" class="data row7 col4" >0.6289</td>
#       <td id="T_e174a_row7_col5" class="data row7 col5" >0.6772</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e174a_row8_col0" class="data row8 col0" >70.6667</td>
#       <td id="T_e174a_row8_col1" class="data row8 col1" >10373.5556</td>
#       <td id="T_e174a_row8_col2" class="data row8 col2" >101.8507</td>
#       <td id="T_e174a_row8_col3" class="data row8 col3" >0.7491</td>
#       <td id="T_e174a_row8_col4" class="data row8 col4" >0.6696</td>
#       <td id="T_e174a_row8_col5" class="data row8 col5" >1.0065</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e174a_row9_col0" class="data row9 col0" >56.9839</td>
#       <td id="T_e174a_row9_col1" class="data row9 col1" >7602.6613</td>
#       <td id="T_e174a_row9_col2" class="data row9 col2" >87.1932</td>
#       <td id="T_e174a_row9_col3" class="data row9 col3" >0.6865</td>
#       <td id="T_e174a_row9_col4" class="data row9 col4" >0.6973</td>
#       <td id="T_e174a_row9_col5" class="data row9 col5" >1.0193</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e174a_row10_col0" class="data row10 col0" >61.0206</td>
#       <td id="T_e174a_row10_col1" class="data row10 col1" >8822.2995</td>
#       <td id="T_e174a_row10_col2" class="data row10 col2" >92.7294</td>
#       <td id="T_e174a_row10_col3" class="data row10 col3" >0.7166</td>
#       <td id="T_e174a_row10_col4" class="data row10 col4" >0.6152</td>
#       <td id="T_e174a_row10_col5" class="data row10 col5" >0.7702</td>
#     </tr>
#     <tr>
#       <th id="T_e174a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e174a_row11_col0" class="data row11 col0" >9.9083</td>
#       <td id="T_e174a_row11_col1" class="data row11 col1" >2829.7144</td>
#       <td id="T_e174a_row11_col2" class="data row11 col2" >14.9517</td>
#       <td id="T_e174a_row11_col3" class="data row11 col3" >0.0679</td>
#       <td id="T_e174a_row11_col4" class="data row11 col4" >0.0752</td>
#       <td id="T_e174a_row11_col5" class="data row11 col5" >0.2111</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Blending and Stacking
#
# * **Blend** trains a Voting Regressor for select models passed in the estimator_list param. It creates multiple models and then averages the individual predictions to form a final prediction.
#
#
# * **Stack** trains a meta model over select estimators passed in the estimator_list parameter. Stacking is another popular technique for ensembling but is less commonly implemented due to practical difficulties. Stacking is an ensemble learning technique that combines multiple models via a meta-model. Another way to think about stacking is that multiple models are trained to predict the outcome and a meta-model is created that uses the predictions from those models as an input along with the original features. The implementation of stack_models() is based on Wolpert, D. H. (1992b). Stacked generalization

# %%
top3_exp1
# Out:
# [XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=-1,
#               num_parallel_tree=1, predictor='auto', random_state=555, ...),
#  LGBMRegressor(random_state=555),
#  ExtraTreesRegressor(n_jobs=-1, random_state=555)]

# %%
blender = exp1.blend_models(estimator_list = top3_exp1)
# you can use any mix of models:) for example ['rf','xgboost', 'lr']
# Out:
# <style type="text/css">
# #T_f4e60_row10_col0, #T_f4e60_row10_col1, #T_f4e60_row10_col2, #T_f4e60_row10_col3, #T_f4e60_row10_col4, #T_f4e60_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f4e60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4e60_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f4e60_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f4e60_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f4e60_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f4e60_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f4e60_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4e60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4e60_row0_col0" class="data row0 col0" >49.6531</td>
#       <td id="T_f4e60_row0_col1" class="data row0 col1" >4473.5305</td>
#       <td id="T_f4e60_row0_col2" class="data row0 col2" >66.8845</td>
#       <td id="T_f4e60_row0_col3" class="data row0 col3" >0.8416</td>
#       <td id="T_f4e60_row0_col4" class="data row0 col4" >0.4265</td>
#       <td id="T_f4e60_row0_col5" class="data row0 col5" >0.4286</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4e60_row1_col0" class="data row1 col0" >31.3824</td>
#       <td id="T_f4e60_row1_col1" class="data row1 col1" >2969.5373</td>
#       <td id="T_f4e60_row1_col2" class="data row1 col2" >54.4935</td>
#       <td id="T_f4e60_row1_col3" class="data row1 col3" >0.9088</td>
#       <td id="T_f4e60_row1_col4" class="data row1 col4" >0.4459</td>
#       <td id="T_f4e60_row1_col5" class="data row1 col5" >0.5166</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4e60_row2_col0" class="data row2 col0" >49.7719</td>
#       <td id="T_f4e60_row2_col1" class="data row2 col1" >5522.7372</td>
#       <td id="T_f4e60_row2_col2" class="data row2 col2" >74.3151</td>
#       <td id="T_f4e60_row2_col3" class="data row2 col3" >0.8044</td>
#       <td id="T_f4e60_row2_col4" class="data row2 col4" >0.5976</td>
#       <td id="T_f4e60_row2_col5" class="data row2 col5" >0.9488</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4e60_row3_col0" class="data row3 col0" >34.7771</td>
#       <td id="T_f4e60_row3_col1" class="data row3 col1" >2628.6151</td>
#       <td id="T_f4e60_row3_col2" class="data row3 col2" >51.2700</td>
#       <td id="T_f4e60_row3_col3" class="data row3 col3" >0.8653</td>
#       <td id="T_f4e60_row3_col4" class="data row3 col4" >0.4706</td>
#       <td id="T_f4e60_row3_col5" class="data row3 col5" >0.4859</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4e60_row4_col0" class="data row4 col0" >44.3520</td>
#       <td id="T_f4e60_row4_col1" class="data row4 col1" >4689.5722</td>
#       <td id="T_f4e60_row4_col2" class="data row4 col2" >68.4805</td>
#       <td id="T_f4e60_row4_col3" class="data row4 col3" >0.8362</td>
#       <td id="T_f4e60_row4_col4" class="data row4 col4" >0.5510</td>
#       <td id="T_f4e60_row4_col5" class="data row4 col5" >0.6497</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f4e60_row5_col0" class="data row5 col0" >58.3114</td>
#       <td id="T_f4e60_row5_col1" class="data row5 col1" >8433.3636</td>
#       <td id="T_f4e60_row5_col2" class="data row5 col2" >91.8333</td>
#       <td id="T_f4e60_row5_col3" class="data row5 col3" >0.7865</td>
#       <td id="T_f4e60_row5_col4" class="data row5 col4" >0.5279</td>
#       <td id="T_f4e60_row5_col5" class="data row5 col5" >0.6122</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f4e60_row6_col0" class="data row6 col0" >38.7094</td>
#       <td id="T_f4e60_row6_col1" class="data row6 col1" >3332.7365</td>
#       <td id="T_f4e60_row6_col2" class="data row6 col2" >57.7299</td>
#       <td id="T_f4e60_row6_col3" class="data row6 col3" >0.8917</td>
#       <td id="T_f4e60_row6_col4" class="data row6 col4" >0.6909</td>
#       <td id="T_f4e60_row6_col5" class="data row6 col5" >0.8968</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f4e60_row7_col0" class="data row7 col0" >56.1054</td>
#       <td id="T_f4e60_row7_col1" class="data row7 col1" >6865.2967</td>
#       <td id="T_f4e60_row7_col2" class="data row7 col2" >82.8571</td>
#       <td id="T_f4e60_row7_col3" class="data row7 col3" >0.8319</td>
#       <td id="T_f4e60_row7_col4" class="data row7 col4" >0.5366</td>
#       <td id="T_f4e60_row7_col5" class="data row7 col5" >0.6947</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f4e60_row8_col0" class="data row8 col0" >53.6284</td>
#       <td id="T_f4e60_row8_col1" class="data row8 col1" >5709.3609</td>
#       <td id="T_f4e60_row8_col2" class="data row8 col2" >75.5603</td>
#       <td id="T_f4e60_row8_col3" class="data row8 col3" >0.8619</td>
#       <td id="T_f4e60_row8_col4" class="data row8 col4" >0.5695</td>
#       <td id="T_f4e60_row8_col5" class="data row8 col5" >0.8178</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f4e60_row9_col0" class="data row9 col0" >40.2156</td>
#       <td id="T_f4e60_row9_col1" class="data row9 col1" >4468.5380</td>
#       <td id="T_f4e60_row9_col2" class="data row9 col2" >66.8471</td>
#       <td id="T_f4e60_row9_col3" class="data row9 col3" >0.8158</td>
#       <td id="T_f4e60_row9_col4" class="data row9 col4" >0.6043</td>
#       <td id="T_f4e60_row9_col5" class="data row9 col5" >0.7966</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f4e60_row10_col0" class="data row10 col0" >45.6907</td>
#       <td id="T_f4e60_row10_col1" class="data row10 col1" >4909.3288</td>
#       <td id="T_f4e60_row10_col2" class="data row10 col2" >69.0271</td>
#       <td id="T_f4e60_row10_col3" class="data row10 col3" >0.8444</td>
#       <td id="T_f4e60_row10_col4" class="data row10 col4" >0.5421</td>
#       <td id="T_f4e60_row10_col5" class="data row10 col5" >0.6848</td>
#     </tr>
#     <tr>
#       <th id="T_f4e60_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f4e60_row11_col0" class="data row11 col0" >8.7604</td>
#       <td id="T_f4e60_row11_col1" class="data row11 col1" >1707.1483</td>
#       <td id="T_f4e60_row11_col2" class="data row11 col2" >12.0243</td>
#       <td id="T_f4e60_row11_col3" class="data row11 col3" >0.0362</td>
#       <td id="T_f4e60_row11_col4" class="data row11 col4" >0.0761</td>
#       <td id="T_f4e60_row11_col5" class="data row11 col5" >0.1688</td>
#     </tr>
#   </tbody>
# </table>

# %%
blender
# Out:
# VotingRegressor(estimators=[('Extreme Gradient Boosting',
#                              XGBRegressor(base_score=0.5, booster='gbtree',
#                                           callbacks=None, colsample_bylevel=1,
#                                           colsample_bynode=1,
#                                           colsample_bytree=1,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=0, gpu_id=-1,
#                                           grow_policy='depthwise',
#                                           importance_type=None,
#                                           interaction_constraints=''...
#                                           max_cat_to_onehot=4, max_delta_step=0,
#                                           max_depth=6, max_leaves=0,
#                                           min_child_weight=1, missing=nan,
#                                           monotone_constraints='()',
#                                           n_estimators=100, n_jobs=-1,
#                                           num_parallel_tree=1, predictor='auto',
#                                           random_state=555, ...)),
#                             ('Light Gradient Boosting Machine',
#                              LGBMRegressor(random_state=555)),
#                             ('Extra Trees Regressor',
#                              ExtraTreesRegressor(n_jobs=-1, random_state=555))],
#                 n_jobs=-1)

# %% [markdown]
# Now that we have created a VotingRegressor using the blend_models() function. The model returned by the blend_models function is just like any other model that you would create using create_model() or tune_model(). You can use this model for predictions on unseen data using predict_model() in the same way you would for any other model.

# %%
stacker = exp1.stack_models(estimator_list=top3_exp1)
# Out:
# <style type="text/css">
# #T_3789e_row10_col0, #T_3789e_row10_col1, #T_3789e_row10_col2, #T_3789e_row10_col3, #T_3789e_row10_col4, #T_3789e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3789e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3789e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3789e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3789e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3789e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3789e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3789e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3789e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3789e_row0_col0" class="data row0 col0" >49.2498</td>
#       <td id="T_3789e_row0_col1" class="data row0 col1" >4480.4470</td>
#       <td id="T_3789e_row0_col2" class="data row0 col2" >66.9361</td>
#       <td id="T_3789e_row0_col3" class="data row0 col3" >0.8413</td>
#       <td id="T_3789e_row0_col4" class="data row0 col4" >0.4919</td>
#       <td id="T_3789e_row0_col5" class="data row0 col5" >0.4305</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3789e_row1_col0" class="data row1 col0" >31.7426</td>
#       <td id="T_3789e_row1_col1" class="data row1 col1" >3083.2685</td>
#       <td id="T_3789e_row1_col2" class="data row1 col2" >55.5272</td>
#       <td id="T_3789e_row1_col3" class="data row1 col3" >0.9053</td>
#       <td id="T_3789e_row1_col4" class="data row1 col4" >0.4670</td>
#       <td id="T_3789e_row1_col5" class="data row1 col5" >0.4189</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3789e_row2_col0" class="data row2 col0" >51.0724</td>
#       <td id="T_3789e_row2_col1" class="data row2 col1" >5928.7749</td>
#       <td id="T_3789e_row2_col2" class="data row2 col2" >76.9985</td>
#       <td id="T_3789e_row2_col3" class="data row2 col3" >0.7900</td>
#       <td id="T_3789e_row2_col4" class="data row2 col4" >0.6239</td>
#       <td id="T_3789e_row2_col5" class="data row2 col5" >0.9960</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3789e_row3_col0" class="data row3 col0" >35.2578</td>
#       <td id="T_3789e_row3_col1" class="data row3 col1" >2728.7583</td>
#       <td id="T_3789e_row3_col2" class="data row3 col2" >52.2375</td>
#       <td id="T_3789e_row3_col3" class="data row3 col3" >0.8601</td>
#       <td id="T_3789e_row3_col4" class="data row3 col4" >0.6511</td>
#       <td id="T_3789e_row3_col5" class="data row3 col5" >0.6314</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3789e_row4_col0" class="data row4 col0" >41.2425</td>
#       <td id="T_3789e_row4_col1" class="data row4 col1" >4474.8465</td>
#       <td id="T_3789e_row4_col2" class="data row4 col2" >66.8943</td>
#       <td id="T_3789e_row4_col3" class="data row4 col3" >0.8437</td>
#       <td id="T_3789e_row4_col4" class="data row4 col4" >0.4981</td>
#       <td id="T_3789e_row4_col5" class="data row4 col5" >0.5038</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3789e_row5_col0" class="data row5 col0" >59.2772</td>
#       <td id="T_3789e_row5_col1" class="data row5 col1" >8379.0695</td>
#       <td id="T_3789e_row5_col2" class="data row5 col2" >91.5373</td>
#       <td id="T_3789e_row5_col3" class="data row5 col3" >0.7879</td>
#       <td id="T_3789e_row5_col4" class="data row5 col4" >0.5635</td>
#       <td id="T_3789e_row5_col5" class="data row5 col5" >0.8580</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3789e_row6_col0" class="data row6 col0" >38.6771</td>
#       <td id="T_3789e_row6_col1" class="data row6 col1" >3103.4172</td>
#       <td id="T_3789e_row6_col2" class="data row6 col2" >55.7083</td>
#       <td id="T_3789e_row6_col3" class="data row6 col3" >0.8991</td>
#       <td id="T_3789e_row6_col4" class="data row6 col4" >0.6326</td>
#       <td id="T_3789e_row6_col5" class="data row6 col5" >0.6755</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3789e_row7_col0" class="data row7 col0" >55.0568</td>
#       <td id="T_3789e_row7_col1" class="data row7 col1" >6492.9038</td>
#       <td id="T_3789e_row7_col2" class="data row7 col2" >80.5786</td>
#       <td id="T_3789e_row7_col3" class="data row7 col3" >0.8410</td>
#       <td id="T_3789e_row7_col4" class="data row7 col4" >0.5929</td>
#       <td id="T_3789e_row7_col5" class="data row7 col5" >0.6750</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3789e_row8_col0" class="data row8 col0" >53.3472</td>
#       <td id="T_3789e_row8_col1" class="data row8 col1" >5973.8096</td>
#       <td id="T_3789e_row8_col2" class="data row8 col2" >77.2904</td>
#       <td id="T_3789e_row8_col3" class="data row8 col3" >0.8555</td>
#       <td id="T_3789e_row8_col4" class="data row8 col4" >0.6169</td>
#       <td id="T_3789e_row8_col5" class="data row8 col5" >0.8128</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3789e_row9_col0" class="data row9 col0" >40.0820</td>
#       <td id="T_3789e_row9_col1" class="data row9 col1" >4334.8607</td>
#       <td id="T_3789e_row9_col2" class="data row9 col2" >65.8397</td>
#       <td id="T_3789e_row9_col3" class="data row9 col3" >0.8213</td>
#       <td id="T_3789e_row9_col4" class="data row9 col4" >0.6459</td>
#       <td id="T_3789e_row9_col5" class="data row9 col5" >1.1316</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3789e_row10_col0" class="data row10 col0" >45.5005</td>
#       <td id="T_3789e_row10_col1" class="data row10 col1" >4898.0156</td>
#       <td id="T_3789e_row10_col2" class="data row10 col2" >68.9548</td>
#       <td id="T_3789e_row10_col3" class="data row10 col3" >0.8445</td>
#       <td id="T_3789e_row10_col4" class="data row10 col4" >0.5784</td>
#       <td id="T_3789e_row10_col5" class="data row10 col5" >0.7134</td>
#     </tr>
#     <tr>
#       <th id="T_3789e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3789e_row11_col0" class="data row11 col0" >8.8093</td>
#       <td id="T_3789e_row11_col1" class="data row11 col1" >1696.2119</td>
#       <td id="T_3789e_row11_col2" class="data row11 col2" >11.9688</td>
#       <td id="T_3789e_row11_col3" class="data row11 col3" >0.0371</td>
#       <td id="T_3789e_row11_col4" class="data row11 col4" >0.0657</td>
#       <td id="T_3789e_row11_col5" class="data row11 col5" >0.2249</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  !!! It's always good to look at the standard deviation of CV results

# %%
stacker
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('Extreme Gradient Boosting',
#                                XGBRegressor(base_score=0.5, booster='gbtree',
#                                             callbacks=None, colsample_bylevel=1,
#                                             colsample_bynode=1,
#                                             colsample_bytree=1,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0,
#                                             gpu_id=-1, grow_policy='depthwise',
#                                             importance_type=None,
#                                             interaction_constra...
#                                             max_delta_step=0, max_depth=6,
#                                             max_leaves=0, min_child_weight=1,
#                                             missing=nan,
#                                             monotone_constraints='()',
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=1,
#                                             predictor='auto', random_state=555, ...)),
#                               ('Light Gradient Boosting Machine',
#                                LGBMRegressor(random_state=555)),
#                               ('Extra Trees Regressor',
#                                ExtraTreesRegressor(n_jobs=-1,
#                                                    random_state=555))],
#                   final_estimator=LinearRegression(n_jobs=-1), n_jobs=-1)

# %% [markdown]
# By default, the meta model (final model to generate predictions) is Linear Regression. The meta model can be changed using the meta_model parameter. See an example below:

# %%
xgboost = exp1.create_model('xgboost')
stacker_xgboost = exp1.stack_models(top3_exp1, meta_model = xgboost)
# Out:
# <style type="text/css">
# #T_2b64d_row10_col0, #T_2b64d_row10_col1, #T_2b64d_row10_col2, #T_2b64d_row10_col3, #T_2b64d_row10_col4, #T_2b64d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2b64d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b64d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2b64d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2b64d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2b64d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2b64d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2b64d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b64d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b64d_row0_col0" class="data row0 col0" >47.8984</td>
#       <td id="T_2b64d_row0_col1" class="data row0 col1" >4138.2892</td>
#       <td id="T_2b64d_row0_col2" class="data row0 col2" >64.3295</td>
#       <td id="T_2b64d_row0_col3" class="data row0 col3" >0.8534</td>
#       <td id="T_2b64d_row0_col4" class="data row0 col4" >0.4763</td>
#       <td id="T_2b64d_row0_col5" class="data row0 col5" >0.4259</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b64d_row1_col0" class="data row1 col0" >34.0491</td>
#       <td id="T_2b64d_row1_col1" class="data row1 col1" >3522.0666</td>
#       <td id="T_2b64d_row1_col2" class="data row1 col2" >59.3470</td>
#       <td id="T_2b64d_row1_col3" class="data row1 col3" >0.8918</td>
#       <td id="T_2b64d_row1_col4" class="data row1 col4" >0.4751</td>
#       <td id="T_2b64d_row1_col5" class="data row1 col5" >0.4603</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b64d_row2_col0" class="data row2 col0" >55.5250</td>
#       <td id="T_2b64d_row2_col1" class="data row2 col1" >7487.2904</td>
#       <td id="T_2b64d_row2_col2" class="data row2 col2" >86.5291</td>
#       <td id="T_2b64d_row2_col3" class="data row2 col3" >0.7349</td>
#       <td id="T_2b64d_row2_col4" class="data row2 col4" >0.7313</td>
#       <td id="T_2b64d_row2_col5" class="data row2 col5" >1.1079</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b64d_row3_col0" class="data row3 col0" >38.5126</td>
#       <td id="T_2b64d_row3_col1" class="data row3 col1" >3093.4191</td>
#       <td id="T_2b64d_row3_col2" class="data row3 col2" >55.6185</td>
#       <td id="T_2b64d_row3_col3" class="data row3 col3" >0.8414</td>
#       <td id="T_2b64d_row3_col4" class="data row3 col4" >0.5822</td>
#       <td id="T_2b64d_row3_col5" class="data row3 col5" >0.5719</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b64d_row4_col0" class="data row4 col0" >47.0744</td>
#       <td id="T_2b64d_row4_col1" class="data row4 col1" >4849.8912</td>
#       <td id="T_2b64d_row4_col2" class="data row4 col2" >69.6412</td>
#       <td id="T_2b64d_row4_col3" class="data row4 col3" >0.8306</td>
#       <td id="T_2b64d_row4_col4" class="data row4 col4" >0.5470</td>
#       <td id="T_2b64d_row4_col5" class="data row4 col5" >0.6066</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b64d_row5_col0" class="data row5 col0" >53.0988</td>
#       <td id="T_2b64d_row5_col1" class="data row5 col1" >7086.4793</td>
#       <td id="T_2b64d_row5_col2" class="data row5 col2" >84.1812</td>
#       <td id="T_2b64d_row5_col3" class="data row5 col3" >0.8206</td>
#       <td id="T_2b64d_row5_col4" class="data row5 col4" >0.5150</td>
#       <td id="T_2b64d_row5_col5" class="data row5 col5" >0.6090</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b64d_row6_col0" class="data row6 col0" >41.9417</td>
#       <td id="T_2b64d_row6_col1" class="data row6 col1" >3709.5857</td>
#       <td id="T_2b64d_row6_col2" class="data row6 col2" >60.9064</td>
#       <td id="T_2b64d_row6_col3" class="data row6 col3" >0.8794</td>
#       <td id="T_2b64d_row6_col4" class="data row6 col4" >0.6831</td>
#       <td id="T_2b64d_row6_col5" class="data row6 col5" >0.5776</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b64d_row7_col0" class="data row7 col0" >53.8873</td>
#       <td id="T_2b64d_row7_col1" class="data row7 col1" >6747.2444</td>
#       <td id="T_2b64d_row7_col2" class="data row7 col2" >82.1416</td>
#       <td id="T_2b64d_row7_col3" class="data row7 col3" >0.8348</td>
#       <td id="T_2b64d_row7_col4" class="data row7 col4" >0.6582</td>
#       <td id="T_2b64d_row7_col5" class="data row7 col5" >0.7776</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b64d_row8_col0" class="data row8 col0" >55.1904</td>
#       <td id="T_2b64d_row8_col1" class="data row8 col1" >6481.6988</td>
#       <td id="T_2b64d_row8_col2" class="data row8 col2" >80.5090</td>
#       <td id="T_2b64d_row8_col3" class="data row8 col3" >0.8432</td>
#       <td id="T_2b64d_row8_col4" class="data row8 col4" >0.6406</td>
#       <td id="T_2b64d_row8_col5" class="data row8 col5" >1.2897</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b64d_row9_col0" class="data row9 col0" >37.4642</td>
#       <td id="T_2b64d_row9_col1" class="data row9 col1" >3781.1347</td>
#       <td id="T_2b64d_row9_col2" class="data row9 col2" >61.4909</td>
#       <td id="T_2b64d_row9_col3" class="data row9 col3" >0.8441</td>
#       <td id="T_2b64d_row9_col4" class="data row9 col4" >0.6111</td>
#       <td id="T_2b64d_row9_col5" class="data row9 col5" >0.8689</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2b64d_row10_col0" class="data row10 col0" >46.4642</td>
#       <td id="T_2b64d_row10_col1" class="data row10 col1" >5089.7099</td>
#       <td id="T_2b64d_row10_col2" class="data row10 col2" >70.4694</td>
#       <td id="T_2b64d_row10_col3" class="data row10 col3" >0.8374</td>
#       <td id="T_2b64d_row10_col4" class="data row10 col4" >0.5920</td>
#       <td id="T_2b64d_row10_col5" class="data row10 col5" >0.7295</td>
#     </tr>
#     <tr>
#       <th id="T_2b64d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2b64d_row11_col0" class="data row11 col0" >7.6066</td>
#       <td id="T_2b64d_row11_col1" class="data row11 col1" >1595.0875</td>
#       <td id="T_2b64d_row11_col2" class="data row11 col2" >11.1251</td>
#       <td id="T_2b64d_row11_col3" class="data row11 col3" >0.0399</td>
#       <td id="T_2b64d_row11_col4" class="data row11 col4" >0.0836</td>
#       <td id="T_2b64d_row11_col5" class="data row11 col5" >0.2685</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_44b0e_row10_col0, #T_44b0e_row10_col1, #T_44b0e_row10_col2, #T_44b0e_row10_col3, #T_44b0e_row10_col4, #T_44b0e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_44b0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44b0e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_44b0e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_44b0e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_44b0e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_44b0e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_44b0e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44b0e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44b0e_row0_col0" class="data row0 col0" >60.8758</td>
#       <td id="T_44b0e_row0_col1" class="data row0 col1" >7625.6263</td>
#       <td id="T_44b0e_row0_col2" class="data row0 col2" >87.3248</td>
#       <td id="T_44b0e_row0_col3" class="data row0 col3" >0.7299</td>
#       <td id="T_44b0e_row0_col4" class="data row0 col4" >0.5017</td>
#       <td id="T_44b0e_row0_col5" class="data row0 col5" >0.4619</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44b0e_row1_col0" class="data row1 col0" >38.5764</td>
#       <td id="T_44b0e_row1_col1" class="data row1 col1" >5319.6550</td>
#       <td id="T_44b0e_row1_col2" class="data row1 col2" >72.9360</td>
#       <td id="T_44b0e_row1_col3" class="data row1 col3" >0.8365</td>
#       <td id="T_44b0e_row1_col4" class="data row1 col4" >0.4729</td>
#       <td id="T_44b0e_row1_col5" class="data row1 col5" >0.4458</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44b0e_row2_col0" class="data row2 col0" >45.4565</td>
#       <td id="T_44b0e_row2_col1" class="data row2 col1" >4539.5476</td>
#       <td id="T_44b0e_row2_col2" class="data row2 col2" >67.3762</td>
#       <td id="T_44b0e_row2_col3" class="data row2 col3" >0.8392</td>
#       <td id="T_44b0e_row2_col4" class="data row2 col4" >0.6138</td>
#       <td id="T_44b0e_row2_col5" class="data row2 col5" >0.7776</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44b0e_row3_col0" class="data row3 col0" >47.3484</td>
#       <td id="T_44b0e_row3_col1" class="data row3 col1" >6370.4552</td>
#       <td id="T_44b0e_row3_col2" class="data row3 col2" >79.8151</td>
#       <td id="T_44b0e_row3_col3" class="data row3 col3" >0.6734</td>
#       <td id="T_44b0e_row3_col4" class="data row3 col4" >0.5179</td>
#       <td id="T_44b0e_row3_col5" class="data row3 col5" >0.4912</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44b0e_row4_col0" class="data row4 col0" >52.9480</td>
#       <td id="T_44b0e_row4_col1" class="data row4 col1" >7206.1697</td>
#       <td id="T_44b0e_row4_col2" class="data row4 col2" >84.8892</td>
#       <td id="T_44b0e_row4_col3" class="data row4 col3" >0.7484</td>
#       <td id="T_44b0e_row4_col4" class="data row4 col4" >0.5408</td>
#       <td id="T_44b0e_row4_col5" class="data row4 col5" >0.5128</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44b0e_row5_col0" class="data row5 col0" >62.3077</td>
#       <td id="T_44b0e_row5_col1" class="data row5 col1" >9794.6788</td>
#       <td id="T_44b0e_row5_col2" class="data row5 col2" >98.9681</td>
#       <td id="T_44b0e_row5_col3" class="data row5 col3" >0.7520</td>
#       <td id="T_44b0e_row5_col4" class="data row5 col4" >0.6354</td>
#       <td id="T_44b0e_row5_col5" class="data row5 col5" >0.8152</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44b0e_row6_col0" class="data row6 col0" >45.2448</td>
#       <td id="T_44b0e_row6_col1" class="data row6 col1" >4942.2927</td>
#       <td id="T_44b0e_row6_col2" class="data row6 col2" >70.3014</td>
#       <td id="T_44b0e_row6_col3" class="data row6 col3" >0.8394</td>
#       <td id="T_44b0e_row6_col4" class="data row6 col4" >0.6875</td>
#       <td id="T_44b0e_row6_col5" class="data row6 col5" >0.7702</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44b0e_row7_col0" class="data row7 col0" >62.2308</td>
#       <td id="T_44b0e_row7_col1" class="data row7 col1" >8267.4774</td>
#       <td id="T_44b0e_row7_col2" class="data row7 col2" >90.9257</td>
#       <td id="T_44b0e_row7_col3" class="data row7 col3" >0.7975</td>
#       <td id="T_44b0e_row7_col4" class="data row7 col4" >0.6089</td>
#       <td id="T_44b0e_row7_col5" class="data row7 col5" >0.5756</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44b0e_row8_col0" class="data row8 col0" >61.8822</td>
#       <td id="T_44b0e_row8_col1" class="data row8 col1" >8047.9296</td>
#       <td id="T_44b0e_row8_col2" class="data row8 col2" >89.7103</td>
#       <td id="T_44b0e_row8_col3" class="data row8 col3" >0.8053</td>
#       <td id="T_44b0e_row8_col4" class="data row8 col4" >0.4789</td>
#       <td id="T_44b0e_row8_col5" class="data row8 col5" >0.5793</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44b0e_row9_col0" class="data row9 col0" >57.2495</td>
#       <td id="T_44b0e_row9_col1" class="data row9 col1" >9392.7668</td>
#       <td id="T_44b0e_row9_col2" class="data row9 col2" >96.9163</td>
#       <td id="T_44b0e_row9_col3" class="data row9 col3" >0.6127</td>
#       <td id="T_44b0e_row9_col4" class="data row9 col4" >0.5972</td>
#       <td id="T_44b0e_row9_col5" class="data row9 col5" >0.7476</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_44b0e_row10_col0" class="data row10 col0" >53.4120</td>
#       <td id="T_44b0e_row10_col1" class="data row10 col1" >7150.6599</td>
#       <td id="T_44b0e_row10_col2" class="data row10 col2" >83.9163</td>
#       <td id="T_44b0e_row10_col3" class="data row10 col3" >0.7635</td>
#       <td id="T_44b0e_row10_col4" class="data row10 col4" >0.5655</td>
#       <td id="T_44b0e_row10_col5" class="data row10 col5" >0.6177</td>
#     </tr>
#     <tr>
#       <th id="T_44b0e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_44b0e_row11_col0" class="data row11 col0" >8.2834</td>
#       <td id="T_44b0e_row11_col1" class="data row11 col1" >1730.7518</td>
#       <td id="T_44b0e_row11_col2" class="data row11 col2" >10.4266</td>
#       <td id="T_44b0e_row11_col3" class="data row11 col3" >0.0722</td>
#       <td id="T_44b0e_row11_col4" class="data row11 col4" >0.0693</td>
#       <td id="T_44b0e_row11_col5" class="data row11 col5" >0.1374</td>
#     </tr>
#   </tbody>
# </table>

# %%
stacker_xgboost
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('Extreme Gradient Boosting',
#                                XGBRegressor(base_score=0.5, booster='gbtree',
#                                             callbacks=None, colsample_bylevel=1,
#                                             colsample_bynode=1,
#                                             colsample_bytree=1,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0,
#                                             gpu_id=-1, grow_policy='depthwise',
#                                             importance_type=None,
#                                             interaction_constra...
#                                                gpu_id=-1,
#                                                grow_policy='depthwise',
#                                                importance_type=None,
#                                                interaction_constraints='',
#                                                learning_rate=0.300000012,
#                                                max_bin=256,
#                                                max_cat_threshold=64,
#                                                max_cat_to_onehot=4,
#                                                max_delta_step=0, max_depth=6,
#                                                max_leaves=0, min_child_weight=1,
#                                                missing=nan,
#                                                monotone_constraints='()',
#                                                n_estimators=100, n_jobs=-1,
#                                                num_parallel_tree=1,
#                                                predictor='auto',
#                                                random_state=555, ...),
#                   n_jobs=-1)

# %% [markdown]
# Before we wrap up this section, there is another parameter in stack_models() that we haven't seen yet called restack. This parameter controls the ability to expose the raw data to the meta model. When set to True, it exposes the raw data to the meta model along with all the predictions of the base level models. By default it is set to True

# %% [markdown]
# ## AutoML
#
# This function returns the best model out of all trained models in current session based on the optimize parameter. Metrics evaluated can be accessed using the get_metrics function.
#
# *I don't recommend doing it this way! very slow!*

# %%
# we already have top3_expr1, blender and stacker so far. Let's make tuned_top3_expr1 and pick the best one. 

tuned_top3_expr = [exp1.tune_model(i) for i in top3_exp1]
best_R2_model = exp1.automl(optimize = 'R2')
# Out:
# <style type="text/css">
# #T_7ff04_row10_col0, #T_7ff04_row10_col1, #T_7ff04_row10_col2, #T_7ff04_row10_col3, #T_7ff04_row10_col4, #T_7ff04_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7ff04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ff04_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7ff04_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7ff04_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7ff04_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7ff04_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7ff04_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ff04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ff04_row0_col0" class="data row0 col0" >52.0442</td>
#       <td id="T_7ff04_row0_col1" class="data row0 col1" >4731.2659</td>
#       <td id="T_7ff04_row0_col2" class="data row0 col2" >68.7842</td>
#       <td id="T_7ff04_row0_col3" class="data row0 col3" >0.8324</td>
#       <td id="T_7ff04_row0_col4" class="data row0 col4" >0.4804</td>
#       <td id="T_7ff04_row0_col5" class="data row0 col5" >0.4693</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ff04_row1_col0" class="data row1 col0" >34.2464</td>
#       <td id="T_7ff04_row1_col1" class="data row1 col1" >2910.3166</td>
#       <td id="T_7ff04_row1_col2" class="data row1 col2" >53.9474</td>
#       <td id="T_7ff04_row1_col3" class="data row1 col3" >0.9106</td>
#       <td id="T_7ff04_row1_col4" class="data row1 col4" >0.6517</td>
#       <td id="T_7ff04_row1_col5" class="data row1 col5" >0.6745</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ff04_row2_col0" class="data row2 col0" >42.3598</td>
#       <td id="T_7ff04_row2_col1" class="data row2 col1" >4168.7450</td>
#       <td id="T_7ff04_row2_col2" class="data row2 col2" >64.5658</td>
#       <td id="T_7ff04_row2_col3" class="data row2 col3" >0.8524</td>
#       <td id="T_7ff04_row2_col4" class="data row2 col4" >0.7173</td>
#       <td id="T_7ff04_row2_col5" class="data row2 col5" >1.1182</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ff04_row3_col0" class="data row3 col0" >38.6412</td>
#       <td id="T_7ff04_row3_col1" class="data row3 col1" >3500.7020</td>
#       <td id="T_7ff04_row3_col2" class="data row3 col2" >59.1667</td>
#       <td id="T_7ff04_row3_col3" class="data row3 col3" >0.8205</td>
#       <td id="T_7ff04_row3_col4" class="data row3 col4" >0.6742</td>
#       <td id="T_7ff04_row3_col5" class="data row3 col5" >0.8055</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ff04_row4_col0" class="data row4 col0" >47.3610</td>
#       <td id="T_7ff04_row4_col1" class="data row4 col1" >4535.8741</td>
#       <td id="T_7ff04_row4_col2" class="data row4 col2" >67.3489</td>
#       <td id="T_7ff04_row4_col3" class="data row4 col3" >0.8416</td>
#       <td id="T_7ff04_row4_col4" class="data row4 col4" >0.7220</td>
#       <td id="T_7ff04_row4_col5" class="data row4 col5" >0.9740</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ff04_row5_col0" class="data row5 col0" >59.3761</td>
#       <td id="T_7ff04_row5_col1" class="data row5 col1" >7593.7696</td>
#       <td id="T_7ff04_row5_col2" class="data row5 col2" >87.1422</td>
#       <td id="T_7ff04_row5_col3" class="data row5 col3" >0.8077</td>
#       <td id="T_7ff04_row5_col4" class="data row5 col4" >0.7019</td>
#       <td id="T_7ff04_row5_col5" class="data row5 col5" >1.2028</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ff04_row6_col0" class="data row6 col0" >40.0462</td>
#       <td id="T_7ff04_row6_col1" class="data row6 col1" >2993.4000</td>
#       <td id="T_7ff04_row6_col2" class="data row6 col2" >54.7120</td>
#       <td id="T_7ff04_row6_col3" class="data row6 col3" >0.9027</td>
#       <td id="T_7ff04_row6_col4" class="data row6 col4" >0.7241</td>
#       <td id="T_7ff04_row6_col5" class="data row6 col5" >1.1231</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ff04_row7_col0" class="data row7 col0" >60.5507</td>
#       <td id="T_7ff04_row7_col1" class="data row7 col1" >6775.9880</td>
#       <td id="T_7ff04_row7_col2" class="data row7 col2" >82.3164</td>
#       <td id="T_7ff04_row7_col3" class="data row7 col3" >0.8340</td>
#       <td id="T_7ff04_row7_col4" class="data row7 col4" >0.8004</td>
#       <td id="T_7ff04_row7_col5" class="data row7 col5" >1.4325</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ff04_row8_col0" class="data row8 col0" >55.9826</td>
#       <td id="T_7ff04_row8_col1" class="data row8 col1" >6789.7116</td>
#       <td id="T_7ff04_row8_col2" class="data row8 col2" >82.3997</td>
#       <td id="T_7ff04_row8_col3" class="data row8 col3" >0.8358</td>
#       <td id="T_7ff04_row8_col4" class="data row8 col4" >0.6597</td>
#       <td id="T_7ff04_row8_col5" class="data row8 col5" >0.9216</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ff04_row9_col0" class="data row9 col0" >40.8836</td>
#       <td id="T_7ff04_row9_col1" class="data row9 col1" >4826.7390</td>
#       <td id="T_7ff04_row9_col2" class="data row9 col2" >69.4747</td>
#       <td id="T_7ff04_row9_col3" class="data row9 col3" >0.8010</td>
#       <td id="T_7ff04_row9_col4" class="data row9 col4" >0.6944</td>
#       <td id="T_7ff04_row9_col5" class="data row9 col5" >1.0271</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7ff04_row10_col0" class="data row10 col0" >47.1492</td>
#       <td id="T_7ff04_row10_col1" class="data row10 col1" >4882.6512</td>
#       <td id="T_7ff04_row10_col2" class="data row10 col2" >68.9858</td>
#       <td id="T_7ff04_row10_col3" class="data row10 col3" >0.8439</td>
#       <td id="T_7ff04_row10_col4" class="data row10 col4" >0.6826</td>
#       <td id="T_7ff04_row10_col5" class="data row10 col5" >0.9749</td>
#     </tr>
#     <tr>
#       <th id="T_7ff04_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7ff04_row11_col0" class="data row11 col0" >8.8467</td>
#       <td id="T_7ff04_row11_col1" class="data row11 col1" >1568.3394</td>
#       <td id="T_7ff04_row11_col2" class="data row11 col2" >11.1180</td>
#       <td id="T_7ff04_row11_col3" class="data row11 col3" >0.0346</td>
#       <td id="T_7ff04_row11_col4" class="data row11 col4" >0.0783</td>
#       <td id="T_7ff04_row11_col5" class="data row11 col5" >0.2615</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# <style type="text/css">
# #T_c0f63_row10_col0, #T_c0f63_row10_col1, #T_c0f63_row10_col2, #T_c0f63_row10_col3, #T_c0f63_row10_col4, #T_c0f63_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c0f63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0f63_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c0f63_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c0f63_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c0f63_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c0f63_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c0f63_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0f63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0f63_row0_col0" class="data row0 col0" >70.5938</td>
#       <td id="T_c0f63_row0_col1" class="data row0 col1" >7708.2250</td>
#       <td id="T_c0f63_row0_col2" class="data row0 col2" >87.7965</td>
#       <td id="T_c0f63_row0_col3" class="data row0 col3" >0.7270</td>
#       <td id="T_c0f63_row0_col4" class="data row0 col4" >0.7091</td>
#       <td id="T_c0f63_row0_col5" class="data row0 col5" >0.9090</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0f63_row1_col0" class="data row1 col0" >50.6076</td>
#       <td id="T_c0f63_row1_col1" class="data row1 col1" >5381.6227</td>
#       <td id="T_c0f63_row1_col2" class="data row1 col2" >73.3595</td>
#       <td id="T_c0f63_row1_col3" class="data row1 col3" >0.8346</td>
#       <td id="T_c0f63_row1_col4" class="data row1 col4" >0.6792</td>
#       <td id="T_c0f63_row1_col5" class="data row1 col5" >0.9062</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0f63_row2_col0" class="data row2 col0" >60.4331</td>
#       <td id="T_c0f63_row2_col1" class="data row2 col1" >6496.2061</td>
#       <td id="T_c0f63_row2_col2" class="data row2 col2" >80.5990</td>
#       <td id="T_c0f63_row2_col3" class="data row2 col3" >0.7699</td>
#       <td id="T_c0f63_row2_col4" class="data row2 col4" >0.9304</td>
#       <td id="T_c0f63_row2_col5" class="data row2 col5" >2.3392</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c0f63_row3_col0" class="data row3 col0" >52.9420</td>
#       <td id="T_c0f63_row3_col1" class="data row3 col1" >4296.0092</td>
#       <td id="T_c0f63_row3_col2" class="data row3 col2" >65.5439</td>
#       <td id="T_c0f63_row3_col3" class="data row3 col3" >0.7798</td>
#       <td id="T_c0f63_row3_col4" class="data row3 col4" >0.8932</td>
#       <td id="T_c0f63_row3_col5" class="data row3 col5" >1.7677</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c0f63_row4_col0" class="data row4 col0" >60.8344</td>
#       <td id="T_c0f63_row4_col1" class="data row4 col1" >6600.2347</td>
#       <td id="T_c0f63_row4_col2" class="data row4 col2" >81.2418</td>
#       <td id="T_c0f63_row4_col3" class="data row4 col3" >0.7695</td>
#       <td id="T_c0f63_row4_col4" class="data row4 col4" >0.8985</td>
#       <td id="T_c0f63_row4_col5" class="data row4 col5" >1.7930</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c0f63_row5_col0" class="data row5 col0" >76.7173</td>
#       <td id="T_c0f63_row5_col1" class="data row5 col1" >10758.1046</td>
#       <td id="T_c0f63_row5_col2" class="data row5 col2" >103.7213</td>
#       <td id="T_c0f63_row5_col3" class="data row5 col3" >0.7276</td>
#       <td id="T_c0f63_row5_col4" class="data row5 col4" >1.0248</td>
#       <td id="T_c0f63_row5_col5" class="data row5 col5" >2.3638</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c0f63_row6_col0" class="data row6 col0" >54.3412</td>
#       <td id="T_c0f63_row6_col1" class="data row6 col1" >5111.8253</td>
#       <td id="T_c0f63_row6_col2" class="data row6 col2" >71.4970</td>
#       <td id="T_c0f63_row6_col3" class="data row6 col3" >0.8339</td>
#       <td id="T_c0f63_row6_col4" class="data row6 col4" >1.0172</td>
#       <td id="T_c0f63_row6_col5" class="data row6 col5" >1.2052</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c0f63_row7_col0" class="data row7 col0" >72.9386</td>
#       <td id="T_c0f63_row7_col1" class="data row7 col1" >9941.4041</td>
#       <td id="T_c0f63_row7_col2" class="data row7 col2" >99.7066</td>
#       <td id="T_c0f63_row7_col3" class="data row7 col3" >0.7565</td>
#       <td id="T_c0f63_row7_col4" class="data row7 col4" >0.9757</td>
#       <td id="T_c0f63_row7_col5" class="data row7 col5" >1.9173</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c0f63_row8_col0" class="data row8 col0" >69.4570</td>
#       <td id="T_c0f63_row8_col1" class="data row8 col1" >9133.3234</td>
#       <td id="T_c0f63_row8_col2" class="data row8 col2" >95.5684</td>
#       <td id="T_c0f63_row8_col3" class="data row8 col3" >0.7791</td>
#       <td id="T_c0f63_row8_col4" class="data row8 col4" >0.8443</td>
#       <td id="T_c0f63_row8_col5" class="data row8 col5" >2.0821</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c0f63_row9_col0" class="data row9 col0" >63.9091</td>
#       <td id="T_c0f63_row9_col1" class="data row9 col1" >7975.9840</td>
#       <td id="T_c0f63_row9_col2" class="data row9 col2" >89.3084</td>
#       <td id="T_c0f63_row9_col3" class="data row9 col3" >0.6712</td>
#       <td id="T_c0f63_row9_col4" class="data row9 col4" >1.0951</td>
#       <td id="T_c0f63_row9_col5" class="data row9 col5" >2.9665</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c0f63_row10_col0" class="data row10 col0" >63.2774</td>
#       <td id="T_c0f63_row10_col1" class="data row10 col1" >7340.2939</td>
#       <td id="T_c0f63_row10_col2" class="data row10 col2" >84.8343</td>
#       <td id="T_c0f63_row10_col3" class="data row10 col3" >0.7649</td>
#       <td id="T_c0f63_row10_col4" class="data row10 col4" >0.9068</td>
#       <td id="T_c0f63_row10_col5" class="data row10 col5" >1.8250</td>
#     </tr>
#     <tr>
#       <th id="T_c0f63_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c0f63_row11_col0" class="data row11 col0" >8.5285</td>
#       <td id="T_c0f63_row11_col1" class="data row11 col1" >2037.9387</td>
#       <td id="T_c0f63_row11_col2" class="data row11 col2" >11.9768</td>
#       <td id="T_c0f63_row11_col3" class="data row11 col3" >0.0467</td>
#       <td id="T_c0f63_row11_col4" class="data row11 col4" >0.1272</td>
#       <td id="T_c0f63_row11_col5" class="data row11 col5" >0.6328</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# #T_eb2fb_row10_col0, #T_eb2fb_row10_col1, #T_eb2fb_row10_col2, #T_eb2fb_row10_col3, #T_eb2fb_row10_col4, #T_eb2fb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eb2fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb2fb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_eb2fb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_eb2fb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_eb2fb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_eb2fb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_eb2fb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb2fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb2fb_row0_col0" class="data row0 col0" >63.6917</td>
#       <td id="T_eb2fb_row0_col1" class="data row0 col1" >7569.3272</td>
#       <td id="T_eb2fb_row0_col2" class="data row0 col2" >87.0019</td>
#       <td id="T_eb2fb_row0_col3" class="data row0 col3" >0.7319</td>
#       <td id="T_eb2fb_row0_col4" class="data row0 col4" >0.5595</td>
#       <td id="T_eb2fb_row0_col5" class="data row0 col5" >0.6106</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb2fb_row1_col0" class="data row1 col0" >47.6388</td>
#       <td id="T_eb2fb_row1_col1" class="data row1 col1" >5696.6954</td>
#       <td id="T_eb2fb_row1_col2" class="data row1 col2" >75.4765</td>
#       <td id="T_eb2fb_row1_col3" class="data row1 col3" >0.8250</td>
#       <td id="T_eb2fb_row1_col4" class="data row1 col4" >0.6278</td>
#       <td id="T_eb2fb_row1_col5" class="data row1 col5" >0.9292</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb2fb_row2_col0" class="data row2 col0" >55.8227</td>
#       <td id="T_eb2fb_row2_col1" class="data row2 col1" >5623.2835</td>
#       <td id="T_eb2fb_row2_col2" class="data row2 col2" >74.9886</td>
#       <td id="T_eb2fb_row2_col3" class="data row2 col3" >0.8009</td>
#       <td id="T_eb2fb_row2_col4" class="data row2 col4" >0.7432</td>
#       <td id="T_eb2fb_row2_col5" class="data row2 col5" >1.4504</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb2fb_row3_col0" class="data row3 col0" >49.8552</td>
#       <td id="T_eb2fb_row3_col1" class="data row3 col1" >4498.7689</td>
#       <td id="T_eb2fb_row3_col2" class="data row3 col2" >67.0729</td>
#       <td id="T_eb2fb_row3_col3" class="data row3 col3" >0.7694</td>
#       <td id="T_eb2fb_row3_col4" class="data row3 col4" >0.7146</td>
#       <td id="T_eb2fb_row3_col5" class="data row3 col5" >1.0621</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb2fb_row4_col0" class="data row4 col0" >63.0888</td>
#       <td id="T_eb2fb_row4_col1" class="data row4 col1" >8215.3948</td>
#       <td id="T_eb2fb_row4_col2" class="data row4 col2" >90.6388</td>
#       <td id="T_eb2fb_row4_col3" class="data row4 col3" >0.7131</td>
#       <td id="T_eb2fb_row4_col4" class="data row4 col4" >0.6284</td>
#       <td id="T_eb2fb_row4_col5" class="data row4 col5" >0.8044</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb2fb_row5_col0" class="data row5 col0" >80.0913</td>
#       <td id="T_eb2fb_row5_col1" class="data row5 col1" >14020.3266</td>
#       <td id="T_eb2fb_row5_col2" class="data row5 col2" >118.4075</td>
#       <td id="T_eb2fb_row5_col3" class="data row5 col3" >0.6450</td>
#       <td id="T_eb2fb_row5_col4" class="data row5 col4" >0.7236</td>
#       <td id="T_eb2fb_row5_col5" class="data row5 col5" >1.0794</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb2fb_row6_col0" class="data row6 col0" >56.3203</td>
#       <td id="T_eb2fb_row6_col1" class="data row6 col1" >7279.3933</td>
#       <td id="T_eb2fb_row6_col2" class="data row6 col2" >85.3194</td>
#       <td id="T_eb2fb_row6_col3" class="data row6 col3" >0.7634</td>
#       <td id="T_eb2fb_row6_col4" class="data row6 col4" >0.7887</td>
#       <td id="T_eb2fb_row6_col5" class="data row6 col5" >1.2975</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb2fb_row7_col0" class="data row7 col0" >77.5708</td>
#       <td id="T_eb2fb_row7_col1" class="data row7 col1" >14149.3694</td>
#       <td id="T_eb2fb_row7_col2" class="data row7 col2" >118.9511</td>
#       <td id="T_eb2fb_row7_col3" class="data row7 col3" >0.6535</td>
#       <td id="T_eb2fb_row7_col4" class="data row7 col4" >0.6722</td>
#       <td id="T_eb2fb_row7_col5" class="data row7 col5" >0.9641</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb2fb_row8_col0" class="data row8 col0" >71.1933</td>
#       <td id="T_eb2fb_row8_col1" class="data row8 col1" >10294.3685</td>
#       <td id="T_eb2fb_row8_col2" class="data row8 col2" >101.4612</td>
#       <td id="T_eb2fb_row8_col3" class="data row8 col3" >0.7510</td>
#       <td id="T_eb2fb_row8_col4" class="data row8 col4" >0.6094</td>
#       <td id="T_eb2fb_row8_col5" class="data row8 col5" >0.8425</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb2fb_row9_col0" class="data row9 col0" >50.3837</td>
#       <td id="T_eb2fb_row9_col1" class="data row9 col1" >6338.5093</td>
#       <td id="T_eb2fb_row9_col2" class="data row9 col2" >79.6148</td>
#       <td id="T_eb2fb_row9_col3" class="data row9 col3" >0.7387</td>
#       <td id="T_eb2fb_row9_col4" class="data row9 col4" >0.7457</td>
#       <td id="T_eb2fb_row9_col5" class="data row9 col5" >1.2195</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eb2fb_row10_col0" class="data row10 col0" >61.5657</td>
#       <td id="T_eb2fb_row10_col1" class="data row10 col1" >8368.5437</td>
#       <td id="T_eb2fb_row10_col2" class="data row10 col2" >89.8932</td>
#       <td id="T_eb2fb_row10_col3" class="data row10 col3" >0.7392</td>
#       <td id="T_eb2fb_row10_col4" class="data row10 col4" >0.6813</td>
#       <td id="T_eb2fb_row10_col5" class="data row10 col5" >1.0260</td>
#     </tr>
#     <tr>
#       <th id="T_eb2fb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_eb2fb_row11_col0" class="data row11 col0" >11.0251</td>
#       <td id="T_eb2fb_row11_col1" class="data row11 col1" >3235.5721</td>
#       <td id="T_eb2fb_row11_col2" class="data row11 col2" >16.9631</td>
#       <td id="T_eb2fb_row11_col3" class="data row11 col3" >0.0545</td>
#       <td id="T_eb2fb_row11_col4" class="data row11 col4" >0.0694</td>
#       <td id="T_eb2fb_row11_col5" class="data row11 col5" >0.2375</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
best_R2_model
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('Extreme Gradient Boosting',
#                                XGBRegressor(base_score=0.5, booster='gbtree',
#                                             callbacks=None, colsample_bylevel=1,
#                                             colsample_bynode=1,
#                                             colsample_bytree=1,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=0,
#                                             gpu_id=-1, grow_policy='depthwise',
#                                             importance_type=None,
#                                             interaction_constra...
#                                             max_delta_step=0, max_depth=6,
#                                             max_leaves=0, min_child_weight=1,
#                                             missing=nan,
#                                             monotone_constraints='()',
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=1,
#                                             predictor='auto', random_state=555, ...)),
#                               ('Light Gradient Boosting Machine',
#                                LGBMRegressor(random_state=555)),
#                               ('Extra Trees Regressor',
#                                ExtraTreesRegressor(n_jobs=-1,
#                                                    random_state=555))],
#                   final_estimator=LinearRegression(n_jobs=-1), n_jobs=-1)

# %% [markdown]
# ## Predict Model
#
# This function predicts Label using a trained model. When data is None, it predicts label on the holdout set.
#
# note: so far, our best model is the stacker model with the highest CV R2. :)

# %%
holdout_pred = exp1.predict_model(stacker)
# Out:
# <style type="text/css">
# </style>
# <table id="T_27607">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27607_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_27607_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_27607_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_27607_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_27607_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_27607_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_27607_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27607_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27607_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_27607_row0_col1" class="data row0 col1" >45.9809</td>
#       <td id="T_27607_row0_col2" class="data row0 col2" >5652.5394</td>
#       <td id="T_27607_row0_col3" class="data row0 col3" >75.1834</td>
#       <td id="T_27607_row0_col4" class="data row0 col4" >0.8342</td>
#       <td id="T_27607_row0_col5" class="data row0 col5" >0.5346</td>
#       <td id="T_27607_row0_col6" class="data row0 col6" >0.5289</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Finalize Model
#
# This function trains a given estimator on the entire dataset including the holdout set.
#
# Model finalization is the last step in the experiment. A normal machine learning workflow in PyCaret starts with setup(), followed by comparing all models using compare_models() and shortlisting a few candidate models (based on the metric of interest) to perform several modeling techniques such as hyperparameter tuning, ensembling, stacking etc. This workflow will eventually lead you to the best model for use in making predictions on new and unseen data. The finalize_model() function fits the model onto the complete dataset including the test/hold-out sample (30% in this case). The purpose of this function is to train the model on the complete dataset before it is deployed in production.

# %%
final_stacker = exp1.finalize_model(stacker)

# %%
final_stacker
# Out:
# Pipeline(memory=Memory(location=C:\Users\jahan\AppData\Local\Temp\joblib),
#          steps=[('placeholder', None),
#                 ('actual_estimator',
#                  StackingRegressor(cv=5,
#                                    estimators=[('Extreme Gradient Boosting',
#                                                 XGBRegressor(base_score=0.5,
#                                                              booster='gbtree',
#                                                              callbacks=None,
#                                                              colsample_bylevel=1,
#                                                              colsample_bynode=1,
#                                                              colsample_bytree=1,
#                                                              early_stopping_rounds=None,
#                                                              enable_categorical=Fa...
#                                                              max_leaves=0,
#                                                              min_child_weight=1,
#                                                              missing=nan,
#                                                              monotone_constraints='()',
#                                                              n_estimators=100,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=1,
#                                                              predictor='auto',
#                                                              random_state=555, ...)),
#                                                ('Light Gradient Boosting '
#                                                 'Machine',
#                                                 LGBMRegressor(random_state=555)),
#                                                ('Extra Trees Regressor',
#                                                 ExtraTreesRegressor(n_jobs=-1,
#                                                                     random_state=555))],
#                                    final_estimator=LinearRegression(n_jobs=-1),
#                                    n_jobs=-1))])

# %% [markdown]
# ### Final prediciton on unseen data
#
# The predict_model() function is also used to predict on the unseen dataset. The only difference from section 11 above is that this time we will pass the data_unseen parameter. data_unseen is the variable created at the beginning of the tutorial and contains 10% of the original dataset which was never exposed to PyCaret.

# %%
unseen_predictions = exp1.predict_model(final_stacker, data=data_unseen)
unseen_predictions.tail()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b773">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b773_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7b773_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7b773_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7b773_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7b773_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7b773_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7b773_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b773_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b773_row0_col0" class="data row0 col0" >Stacking Regressor</td>
#       <td id="T_7b773_row0_col1" class="data row0 col1" >36.1169</td>
#       <td id="T_7b773_row0_col2" class="data row0 col2" >2613.2166</td>
#       <td id="T_7b773_row0_col3" class="data row0 col3" >51.1196</td>
#       <td id="T_7b773_row0_col4" class="data row0 col4" >0.9240</td>
#       <td id="T_7b773_row0_col5" class="data row0 col5" >0.5435</td>
#       <td id="T_7b773_row0_col6" class="data row0 col6" >0.5165</td>
#     </tr>
#   </tbody>
# </table>
#     season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 95       4   1    11   3        0        2           1           3  0.32
# 96       1   1     1  13        0        6           0           1  0.44
# 97       3   0     9   3        0        2           1           1  0.58
# 98       1   1     1  14        0        3           1           2  0.14
# 99       1   0     2   5        0        6           0           2  0.22
#
#      atemp   hum  windspeed  cnt  prediction_label
# 95  0.3333  0.70     0.1343    4        -10.914832
# 96  0.4394  0.44     0.1940  445        316.355426
# 97  0.5455  0.83     0.0000    4         -4.201152
# 98  0.1212  0.46     0.2537   75         81.109700
# 99  0.2424  0.64     0.1045   10         -6.850711

# %% [markdown]
# ## Save Model
#
# This function saves the transformation pipeline and trained model object into the current working directory as a pickle file for later use.

# %%
exp1.save_model(final_stacker, 'my_pycaret_regression')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=C:\Users\jahan\AppData\Local\Temp\joblib),
#           steps=[('placeholder', None),
#                  ('actual_estimator',
#                   StackingRegressor(cv=5,
#                                     estimators=[('Extreme Gradient Boosting',
#                                                  XGBRegressor(base_score=0.5,
#                                                               booster='gbtree',
#                                                               callbacks=None,
#                                                               colsample_bylevel=1,
#                                                               colsample_bynode=1,
#                                                               colsample_bytree=1,
#                                                               early_stopping_rounds=None,
#                                                               enable_categorical=Fa...
#                                                               max_leaves=0,
#                                                               min_child_weight=1,
#                                                               missing=nan,
#                                                               monotone_constraints='()',
#                                                               n_estimators=100,
#                                                               n_jobs=-1,
#                                                               num_parallel_tree=1,
#                                                               predictor='auto',
#                                                               random_state=555, ...)),
#                                                 ('Light Gradient Boosting '
#                                                  'Machine',
#                                                  LGBMRegressor(random_state=555)),
#                                                 ('Extra Trees Regressor',
#                                                  ExtraTreesRegressor(n_jobs=-1,
#                                                                      random_state=555))],
#                                     final_estimator=LinearRegression(n_jobs=-1),
#                                     n_jobs=-1))]),
#  'my_pycaret_regression.pkl')

# %% [markdown]
# ## Load model
#
# This function loads a previously saved pipeline.

# %%
my_winning_regressor = load_model('my_pycaret_regression')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
my_winning_regressor
# Out:
# Pipeline(memory=Memory(location=C:\Users\jahan\AppData\Local\Temp\joblib),
#          steps=[('placeholder', None),
#                 ('actual_estimator',
#                  StackingRegressor(cv=5,
#                                    estimators=[('Light Gradient Boosting '
#                                                 'Machine',
#                                                 LGBMRegressor(random_state=555)),
#                                                ('Extreme Gradient Boosting',
#                                                 XGBRegressor(base_score=0.5,
#                                                              booster='gbtree',
#                                                              callbacks=None,
#                                                              colsample_bylevel=1,
#                                                              colsample_bynode=1,...
#                                                              max_cat_to_onehot=4,
#                                                              max_delta_step=0,
#                                                              max_depth=6,
#                                                              max_leaves=0,
#                                                              min_child_weight=1,
#                                                              missing=nan,
#                                                              monotone_constraints='()',
#                                                              n_estimators=100,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=1,
#                                                              predictor='auto',
#                                                              random_state=555, ...)),
#                                                ('Extra Trees Regressor',
#                                                 ExtraTreesRegressor(n_jobs=-1,
#                                                                     random_state=555))],
#                                    final_estimator=LinearRegression(n_jobs=-1),
#                                    n_jobs=-1, passthrough=True))])

# %% [markdown]
# ## Deploy Model
#
# This function deploys the transformation pipeline and trained model on cloud.
#
# https://pycaret.readthedocs.io/en/latest/api/regression.html#pycaret.regression.deploy_model
